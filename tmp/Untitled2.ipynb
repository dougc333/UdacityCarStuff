# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import os
import json
from skimage.exposure import adjust_gamma
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Convolution2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy import ndimage
from scipy.misc import imresize


# Get steering angles for controlled driving
angles = pd.read_csv('/Users/dc/Desktop/data/driving_log4laps.csv',header=None)
angles.columns = ('Center Image','Left Image','Right Image','Steering Angle','Throttle','Brake','Speed')
angles = np.array(angles['Steering Angle'])

# Get steering angles for recovery driving
recovery_angles = pd.read_csv('/Users/dc/Desktop/recovery/driving_log.csv', header = None)
recovery_angles.columns = ('Center Image','Left Image','Right Image','Steering Angle','Throttle','Brake','Speed')
recovery_angles = np.array(recovery_angles['Steering Angle'])

# Construct arrays for center, right and left images of controlled driving
images = np.asarray(os.listdir("/Users/dc/Desktop/data/IMG_4laps/"))
images = images[1:] # To ignore .DS_store on mac
center = np.ndarray(shape=(len(angles), 20, 64, 3))
right = np.ndarray(shape=(len(angles), 20, 64, 3))
left = np.ndarray(shape=(len(angles), 20, 64, 3))

# Populate controlled driving datasets
# Images are resized to 32x64 to increase training speeds
# The top 12 pixels are cropped off because they contain no useful information for driving behavior
# Final image size to be used in training is 20 x 64 x 3
count = 0
for image in images:
    image_file = os.path.join('/Users/dc/Desktop/data/IMG_4laps/', image)
    if image.startswith('center'):
        image_data = ndimage.imread(image_file).astype(np.float32)
        center[count % len(angles)] = imresize(image_data, (32,64,3))[12:,:,:]
    elif image.startswith('right'):
        image_data = ndimage.imread(image_file).astype(np.float32)
        right[count % len(angles)] = imresize(image_data, (32,64,3))[12:,:,:]
    elif image.startswith('left'):
        image_data = ndimage.imread(image_file).astype(np.float32)
        left[count % len(angles)] = imresize(image_data, (32,64,3))[12:,:,:]
    count += 1

# Construct array for recovery driving images
recovery_images = np.asarray(os.listdir("/Users/dc/Desktop/recovery/IMG/"))
recovery_images = recovery_images[1:] # To ignore .DS_store on mac
recovery = np.ndarray(shape=(len(recovery_angles), 20, 64, 3))

# Populate recovery driving dataset
count = 0
for image in recovery_images:
    image_file = os.path.join('/Users/dc/Desktop/recovery/IMG', image)
    print('processing:', image)
    image_data = ndimage.imread(image_file).astype(np.float32)
    print(image_data.shape)
    recovery[count] = imresize(image_data, (32,64,3))[12:,:,:]
    count += 1

# Concatenate all arrays in to combined training dataset and labels
X_train = np.concatenate((center, right, left, recovery), axis=0)
y_train = np.concatenate((angles, (angles - .08), (angles + .08), recovery_angles),axis=0)

# Adjust gamma in images to increase contrast
X_train = adjust_gamma(X_train)

# Create a mirror image of the images in the dataset to combat left turn bias
mirror = np.ndarray(shape=(X_train.shape))
count = 0
for i in range(len(X_train)):
    mirror[count] = np.fliplr(X_train[i])
    count += 1
mirror.shape

# Create mirror image labels
mirror_angles = y_train * -1

# Combine regular features/labels with mirror features/labels
X_train = np.concatenate((X_train, mirror), axis=0)
y_train = np.concatenate((y_train, mirror_angles),axis=0)

# Perform train/test split to a create validation dataset
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=.05)

# Establish model architecture
model = Sequential()
model.add(BatchNormalization(axis=1, input_shape=(20,64,3)))
model.add(Convolution2D(16, 3, 3, border_mode='valid', subsample=(2,2), activation='relu'))
model.add(Convolution2D(24, 3, 3, border_mode='valid', subsample=(1,2), activation='relu'))
model.add(Convolution2D(36, 3, 3, border_mode='valid', activation='relu'))
model.add(Convolution2D(48, 2, 2, border_mode='valid', activation='relu'))
model.add(Convolution2D(48, 2, 2, border_mode='valid', activation='relu'))
model.add(Flatten())
model.add(Dense(512))
model.add(Dropout(.5))
model.add(Activation('relu'))
model.add(Dense(10))
model.add(Activation('relu'))
model.add(Dense(1))
model.summary()

# Compile model with adam optimizer and learning rate of .0001
adam = Adam(lr=0.0001)
model.compile(loss='mse',
              optimizer=adam)

# Model will save the weights whenever validation loss improves
checkpoint = ModelCheckpoint(filepath = 'model.h5', verbose = 1, save_best_only=True, monitor='val_loss')

# Discontinue training when validation loss fails to decrease
callback = EarlyStopping(monitor='val_loss', patience=2, verbose=1)

# Train model for 20 epochs and a batch size of 128
history = model.fit(X_train,
        y_train,
        nb_epoch=20,
        verbose=1,
        batch_size=128,
        shuffle=True,
        validation_data=(X_val, y_val),
        callbacks=[checkpoint, callback])

print("Weights Saved")
json_string = model.to_json()
with open('model.json', 'w') as jsonfile:
    json.dump(json_string, jsonfile)
print("Model Saved")
# Out:
# processing: center_2017_03_29_05_45_44_390.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_44_486.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_44_582.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_44_676.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_44_772.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_44_867.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_44_962.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_45_058.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_45_154.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_45_249.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_45_343.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_45_439.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_45_535.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_45_630.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_45_728.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_45_823.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_45_916.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_46_012.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_46_108.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_46_208.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_46_308.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_46_410.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_46_541.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_46_641.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_46_741.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_46_842.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_46_910.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_47_012.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_47_110.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_47_209.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_47_308.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_47_409.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_47_513.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_47_612.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_47_714.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_47_813.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_47_911.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_48_010.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_48_111.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_48_210.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_48_307.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_48_402.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_48_500.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_48_599.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_48_699.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_48_800.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_48_901.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_49_004.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_49_106.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_49_183.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_49_262.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_49_366.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_49_472.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_49_577.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_49_682.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_49_788.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_49_894.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_50_003.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_50_116.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_50_228.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_50_337.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_50_448.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_50_559.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_50_673.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_50_783.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_50_895.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_51_008.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_51_120.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_51_234.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_51_348.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_51_461.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_51_574.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_51_687.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_51_802.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_51_915.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_52_028.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_52_140.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_52_254.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_52_368.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_52_487.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_52_603.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_52_712.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_52_826.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_52_941.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_53_057.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_53_172.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_53_288.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_53_395.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_53_509.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_53_625.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_53_739.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_53_853.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_53_967.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_54_081.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_54_196.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_54_310.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_54_432.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_54_546.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_54_659.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_54_777.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_45_54_887.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_54_428.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_54_533.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_54_637.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_54_742.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_54_848.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_54_954.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_55_060.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_55_165.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_55_277.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_55_386.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_55_458.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_55_555.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_55_665.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_55_775.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_55_919.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_56_029.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_56_085.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_56_196.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_56_307.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_56_417.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_56_528.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_56_640.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_56_716.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_56_828.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_56_940.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_57_054.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_57_169.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_57_289.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_57_402.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_57_521.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_57_639.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_57_766.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_57_889.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_58_007.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_58_129.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_58_249.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_58_370.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_58_492.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_58_612.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_58_734.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_58_855.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_58_977.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_59_097.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_59_217.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_59_337.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_59_454.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_59_573.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_59_692.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_59_811.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_48_59_930.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_00_049.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_00_166.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_00_279.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_00_394.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_00_505.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_00_618.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_00_730.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_00_841.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_00_954.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_01_068.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_01_184.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_01_302.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_01_421.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_01_539.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_01_658.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_01_781.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_01_908.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_02_027.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_02_148.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_02_266.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_02_386.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_02_506.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_02_622.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_02_736.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_02_854.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_02_972.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_03_091.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_03_209.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_03_328.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_03_448.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_03_574.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_03_689.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_03_806.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_03_923.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_04_039.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_04_153.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_04_268.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_04_383.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_04_495.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_04_609.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_04_724.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_04_842.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_04_954.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_05_069.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_05_186.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_05_305.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_05_424.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_05_545.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_05_665.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_49_05_787.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_00_129.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_00_244.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_00_361.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_00_479.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_00_597.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_00_712.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_00_827.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_00_943.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_01_060.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_01_176.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_01_293.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_01_409.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_01_525.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_01_642.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_01_758.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_01_874.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_01_991.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_02_109.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_02_263.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_02_378.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_02_494.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_02_612.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_02_729.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_02_809.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_02_965.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_03_046.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_03_164.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_03_283.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_03_401.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_03_518.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_03_676.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_03_795.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_03_915.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_03_996.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_04_116.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_04_236.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_04_359.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_04_483.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_04_604.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_04_726.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_04_842.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_04_967.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_05_082.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_05_203.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_05_321.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_05_441.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_05_560.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_05_679.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_05_797.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_05_916.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_06_035.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_06_155.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_06_272.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_06_394.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_06_510.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_06_629.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_06_752.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_06_874.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_06_989.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_07_110.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_07_228.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_07_348.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_07_463.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_07_584.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_07_702.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_07_825.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_07_942.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_08_063.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_08_181.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_08_293.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_08_408.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_08_525.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_08_646.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_08_766.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_08_881.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_08_999.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_09_117.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_09_235.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_09_353.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_09_470.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_09_589.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_09_707.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_09_826.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_09_944.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_10_065.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_10_181.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_10_296.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_10_415.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_10_532.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_10_651.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_10_769.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_10_886.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_11_004.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_11_123.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_11_241.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_11_360.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_11_477.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_11_595.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_11_712.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_11_834.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_11_950.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_12_070.jpg
# (160, 320, 3)
# processing: center_2017_03_29_05_51_12_189.jpg
# (160, 320, 3)
# ---------------------------------------------------------
# IndexError              Traceback (most recent call last)
# <ipython-input-5-34dd8ab66d84> in <module>()
#      64     image_data = ndimage.imread(image_file).astype(np.float32)
#      65     print(image_data.shape)
# ---> 66     recovery[count] = imresize(image_data, (32,64,3))[12:,:,:]
#      67     count += 1
#      68
#
# IndexError: index 303 is out of bounds for axis 0 with size 303
