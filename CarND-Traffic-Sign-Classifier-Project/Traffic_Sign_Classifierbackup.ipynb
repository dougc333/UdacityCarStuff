# %% [markdown]
# ## Step 0: Load The Data

# %%
# Load pickled data
import matplotlib.pyplot as plt
import pickle, cv2, csv, os
import numpy as np
from numpy import newaxis
from random import randint
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from matplotlib import gridspec
# Visualizations will be shown in the notebook.
# %matplotlib inline

# %%
#careful we have RGB not BGR
#convention uppercase X means list or array, lowercase means single object like image

def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    (assuming your grayscaled image is called 'gray')
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Or use BGR2GRAY if you read an image with cv2.imread()
    # return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

def img_hist(img):
    clahe = cv2.createCLAHE()
    cle = clahe.apply(img)
    return cle 
    
#test wo scalar RGB adjustments; how much difference?
def rgb_to_gray(X_train):
    almost_gray = np.add(np.add(X_train[:,:,:,0],X_train[:,:,:,1]),X_train[:,:,:,2])
    return almost_gray/3.0

#x = 0.299r + 0.587g + 0.114b.
def rgb_gray(X_train):
    gray = np.add(np.add(X_train[:,:,:,0]*.299,X_train[:,:,:,1]*.587),X_train[:,:,:,2]*.114)
    return gray

#gives range [-1,1] vs. [0,1]. [0,1] better b/c no multiply by 0. Test
def normalize(X_train):
    return np.divide(np.subtract(X_train,128.),128.)

#[0,1]
def normalize_pos(X_train):
    return np.divide(X_train,255.)

def apply_hist(X):
    for idx,img in enumerate(X):
        equ = equalize_img(img)
        X[idx] = equ
    return X

def np_grayscale(img):
    return np.array(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY))


def histo(im, nbin=10 ,xmin=0, xmax=255 ,normalized=True):
    ndim = im.ndim
    print (ndim)
    bins = np.linspace(xmin, xmax, nbin+1)
    hsv = matplotlib.colors.rgb_to_hsv(im/xmax) * xmax
    imhist, bin_edges = np.histogram(hsv[:,:,0], bins=bins, density=normalized)
    imhist = imhist * np.diff(bin_edges)
    return imhist


def rgb2gray(rgb_img):
    """
    Convert RGB image to grayscale
    Parameters:
      rgb_img : RGB image

    Returns:
      grayscale image

  """
    return np.dot(rgb_img[...,:3], [0.299, 0.587, 0.144])


#input grayscale
#output grayscale 
def equalize_img(img):
    return cv2.equalizeHist(img.astype(np.uint8))

#input: RGB image, integer for grayscale conversion
#output: greyscale image
#note to myself. Reformatting from (32,32) to (32,32,1) wont plot
#(32,32) will plot but wont fit into the NN. The NN wants (32,32,1) but this wont plot. 
#X_train_fixdims = X_train_normalized[...,newaxis] used for converting from (32,32)->(32,32,1)
def preprocess(X,version):
    if version==0:
        X_train_gray = rgb_gray(X)
    elif version==1:
        X_train_gray = rbg_to_gray(X)
    elif version == 2:
        X_train_gray = np_grayscale(X)
    elif version==3:
        X_train_gray = greyscale(X)
    else:
        print('error preprocess invalid grayscale version')
    X_histo = apply_hist(X_train_gray)
    X_train_normalized = normalize_pos(X_histo)
    # I never saw a difference w/ float64!!
    X_train_normalized = X_train_normalized.astype(np.float32)-np.mean(X_train_normalized).astype(np.float32)
    return X_train_normalized


def load_data():
    training_file = 'train.p'
    testing_file = 'test.p'
    valid_file = 'valid.p'
    old_training_file = 'trainold.p'

    with open(training_file, mode='rb') as f:
        train = pickle.load(f)
    with open(testing_file, mode='rb') as f:
        test = pickle.load(f)
    with open(valid_file, mode='rb') as f:
        valid = pickle.load(f)
    with open(old_training_file, mode='rb') as f:
        old_train = pickle.load(f)

        
    X_train, y_train, X_test, y_test = train['features'], train['labels'],test['features'], test['labels']
    X_valid, y_valid = test['features'], test['labels']
    O_train = old_train['features']
    
    return X_train, y_train, X_test, y_test, X_valid, y_valid, O_train



def clearAddedData():
    global rot
    global orig
    global labels
    rot = []
    orig = []
    labels = []
    

def load_csv():
    csv_dict = {}

    with open(os.getcwd()+'/signnames.csv', 'rt') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        for row in reader:
            if (row[0]!='ClassId'):
                csv_dict[int(row[0])] = row[1]

    return csv_dict

# process data to grayscale 0 mean over range +/- 1 
# you can plot X_train_pp but you cannot plot X_train_pp_format
# we need both versions for debugging. 
def preprocess_data():
    X_train_pp = preprocess(X_train,version=0)
    X_test_pp = preprocess(X_test,version=0)
    X_valid_pp = preprocess(X_valid,version=0)
       
# matplotlib cant plot these
# Note: can also do X_train_pp_format = X_train_pp[...,None] to add the extra axis
    X_train_pp_format = X_train_pp[...,newaxis]
    X_test_pp_format = X_test_pp[...,newaxis]
    X_valid_pp_format = X_valid_pp[...,newaxis]
    return X_train_pp, X_test_pp, X_valid_pp, X_train_pp_format, X_test_pp_format, X_valid_pp_format

# %%
# load csv_dict for plots
csv_dict = load_csv()
print (csv_dict)

clearAddedData()
# Out:
# {0: 'Speed limit (20km/h)', 1: 'Speed limit (30km/h)', 2: 'Speed limit (50km/h)', 3: 'Speed limit (60km/h)', 4: 'Speed limit (70km/h)', 5: 'Speed limit (80km/h)', 6: 'End of speed limit (80km/h)', 7: 'Speed limit (100km/h)', 8: 'Speed limit (120km/h)', 9: 'No passing', 10: 'No passing for vehicles over 3.5 metric tons', 11: 'Right-of-way at the next intersection', 12: 'Priority road', 13: 'Yield', 14: 'Stop', 15: 'No vehicles', 16: 'Vehicles over 3.5 metric tons prohibited', 17: 'No entry', 18: 'General caution', 19: 'Dangerous curve to the left', 20: 'Dangerous curve to the right', 21: 'Double curve', 22: 'Bumpy road', 23: 'Slippery road', 24: 'Road narrows on the right', 25: 'Road work', 26: 'Traffic signals', 27: 'Pedestrians', 28: 'Children crossing', 29: 'Bicycles crossing', 30: 'Beware of ice/snow', 31: 'Wild animals crossing', 32: 'End of all speed and passing limits', 33: 'Turn right ahead', 34: 'Turn left ahead', 35: 'Ahead only', 36: 'Go straight or right', 37: 'Go straight or left', 38: 'Keep right', 39: 'Keep left', 40: 'Roundabout mandatory', 41: 'End of no passing', 42: 'End of no passing by vehicles over 3.5 metric tons'}

# %%
# TODO: Fill this in based on where you saved the training and testing dat
# the .p files are preprocessed from the download site above

X_train, y_train, X_test, y_test, X_valid, y_valid, O_train = load_data()

# we need these later: train['sizes'], train['coords']
# test['sizes'], test['coords']

print ('X_train shape:',(X_train.shape , 'y_train (labels for X_train) shape:', y_train.shape))
print ('X_test shape:',(X_test.shape), 'y_test (labels for X_test) shape:',(y_test.shape))
#print ('bounding box coordinates of training image 0:', train['coords'][0])
print ('X_valid shape:',(X_valid.shape), 'y_valid (labels for X_train) shape:', y_valid.shape)


#plot the original image. The dataset changed as I was doing the assignment. 
#The original X_train[0] was a 20kmh speed sign in color now we have a grayish End of no passing sign
# they look blurred compared to the original. This is I assume an artifact of creating images for the assignment
# they also look shuffled.

gs1 = gridspec.GridSpec(1, 2)
#this spacing doesnt make a difference
gs1.update(wspace=2.0, hspace= 2.0)
plt.subplot(1,2,1)
plt.imshow(X_train[0])
plt.title('X_train[0] current')
plt.subplot(1,2,2)
plt.imshow(O_train[0])
plt.title('orig X_train[0]')
# Out:
# X_train shape: ((34799, 32, 32, 3), 'y_train (labels for X_train) shape:', (34799,))
# X_test shape: (12630, 32, 32, 3) y_test (labels for X_test) shape: (12630,)
# X_valid shape: (12630, 32, 32, 3) y_valid (labels for X_train) shape: (12630,)

# %%
# does the new train.p dataset contain color? Did they preprocess the color out? No longer matches the download 
# from the website where the first image is clearly the one on the right. 
# this shows old training set and new set{train.p, valid.p, test.p are different}

for idx,img in enumerate(X_train):
    if( np.array_equal(X_train[idx],O_train[0])):
        print('found')

for idx,img in enumerate(X_valid):
    if( np.array_equal(X_valid[idx],O_train[0])):
        print('found')

# not good...this means I need to create my own dataset from the download bc I have no idea what the train.p is. 
#try reverse search,

for idx,img in enumerate(O_train):
    if( np.array_equal(O_train[idx],X_train[0])):
        print('found')

for idx,img in enumerate(X_valid):
    if( np.array_equal(X_valid[idx],X_train[0])):
        print('found')

#error check, make sure images in the test set and validation set are not duplicates

# %%
# test normalization of histograms in hsv space and or using canned routines. 

#looks like they preprocessed the images. Moved to grayscale already
#the original didnt have this
im=O_train[0]
plt.hist(histo(O_train[0]))
# Out:
# 3
# 3
# (array([ 4.,  2.,  1.,  1.,  0.,  0.,  0.,  0.,  0.,  2.]),
#  array([ 0.04003906,  0.059375  ,  0.07871094,  0.09804688,  0.11738281,
#          0.13671875,  0.15605469,  0.17539062,  0.19472656,  0.2140625 ,
#          0.23339844]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(histo(X_train[0]))
print(X_train[0].ndim)
# Out:
# 3
# 3

# %%
#plot the 2 images before and after histogram equalization
#plt.imhist(histo(img_20km))
#plt.imhist(histo(img_no))

h,w,depth = X_train[0].shape
vis2=np.zeros((h,w),np.float32)
print (vis2.shape,type(vis2))


G_Train = rgb_gray(X_train)
print (G_Train[0].shape)
print (type(G_Train[0][0]))
equ = cv2.equalizeHist(G_Train[0].astype(np.uint8))
#it does LOOK lighter!! or brighter. but the edges look worse? 
print ('equ.shape:',equ.shape)


#plt.imshow(equ,cmap='gray')
gs1 = gridspec.GridSpec(1, 2)
#this spacing doesnt make a difference
gs1.update(wspace=2.0, hspace= 2.0)
plt.subplot(1,2,1)
plt.imshow(X_train[0],cmap='gray')
plt.title('original image')
plt.subplot(1,2,2)
plt.imshow(equ,cmap='gray')
plt.title('histogram equalized')
# Out:
# (32, 32) <class 'numpy.ndarray'>
# (32, 32)
# <class 'numpy.ndarray'>
# equ.shape: (32, 32)

# %%
# the peak is in the middle with density=False, is on LHS near y axis with density=True

print (np.amin(equ),np.amax(equ))
print ('moved mean from:',np.mean(X_train[0]),' to:',np.mean(equ))
plt.hist(np.histogram(equ, bins=10 ,density=False))

#note density=False and density=True give 2 different plots.
# Out:
# 0 255
# moved mean from: 43.8818359375  to: 132.809570312
# ([array([ 1.,  0.,  0.,  1.,  7.,  0.,  1.,  0.,  0.,  0.]),
#   array([ 1.,  1.,  1.,  1.,  1.,  1.,  1.,  1.,  1.,  2.])],
#  array([   0. ,   25.5,   51. ,   76.5,  102. ,  127.5,  153. ,  178.5,
#          204. ,  229.5,  255. ]),
#  <a list of 2 Lists of Patches objects>)

# %%
# process loaded data

X_train_pp, X_test_pp, X_valid_pp, X_train_pp_format, X_test_pp_format, X_valid_pp_format = preprocess_data()


print('X_train_pp shape:', X_train_pp.shape)
print('X_test_pp shape:', X_test_pp.shape)
print('X_valid_pp shape:', X_valid_pp.shape)

print('X_train_pp_format shape:', X_train_pp_format.shape)
print('X_test_pp_format shape:', X_test_pp_format.shape)
print('X_valid_pp_format shape:', X_valid_pp_format.shape)


#TBD: find the original image and see if we can clean these up using the bounding box

gs1 = gridspec.GridSpec(3, 2)
gs1.update(wspace=2.0, hspace= 2.0)
plt.subplot(3,2,1)
plt.imshow(X_train[0])
plt.title('orig')
#plt.title(csv_dict[y_train[0]])
#test 
plt.subplot(3,2,2)
plt.imshow(X_test[0])
plt.title('orig')
#plt.title(csv_dict[y_test[0]])

plt.subplot(3,2,3)
plt.imshow(X_train_pp[0],cmap='gray')
plt.title('gray of above')
#plt.title(csv_dict[y_train[0]])

plt.subplot(3,2,4)
plt.imshow(X_test_pp[0],cmap='gray')
plt.title('gray of above')
#plt.title(csv_dict[y_test[0]])

       
plt.subplot(3,2,5)
plt.imshow(X_valid[10],cmap='gray')
plt.title('orig')
#plt.title(csv_dict[y_valid[10]])
       
plt.subplot(3,2,6)
plt.imshow(X_valid_pp[10],cmap='gray')
plt.title('gray of left')
#plt.title(csv_dict[y_valid[10]])
# Out:
# X_train_pp shape: (34799, 32, 32)
# X_test_pp shape: (12630, 32, 32)
# X_valid_pp shape: (12630, 32, 32)
# X_train_pp_format shape: (34799, 32, 32, 1)
# X_test_pp_format shape: (12630, 32, 32, 1)
# X_valid_pp_format shape: (12630, 32, 32, 1)

# %% [markdown]
# #### Image Normalization
# We can see after conversion to grey sacle the edges are enhanced by removing the dark overcast shadows in
# both examples. 1) in the cells below the histogram and the last row of the cell above. The edges in the no passing
# sign and the diagonal sign show up more clear; at least to the human eye.
# An interesting experiment would be to create a separate sobel image set as a set of features similar to what Karpathy
# did. One open question is if the histgram equalization for default=False vs default=True makes a difference. One difference
# would be in creating different mean values after histogram equalization. We adjust the mean back to 0 after histogram equaliaztion.

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below.

# %%
### Replace each question mark with the appropriate value.

# TODO: Number of training examples
n_train = X_train.shape[0]

# TODO: Number of testing examples.
n_test = X_test.shape[0]

# TODO: Number of testing examples.
n_valid = X_valid.shape[0]


# TODO: What's the shape of an traffic sign image?
image_shape = X_train[0].shape

# TODO: How many unique classes/labels there are in the dataset.
n_classes = len(csv_dict)

print("Number of training examples =", n_train, 'number of training labels:', y_train.shape[0])
print("Number of testing examples =", n_test, 'number of testing labels:', y_test.shape[0])
print("Number of validation examples =", n_valid, 'number of valid labels:', y_valid.shape[0])

print("Image data shape =", image_shape)
print("Number of classes =", n_classes)

#verify float32
print('---------------------------')
print ('verify range of data -/+ 1')
print(X_train_pp_format.dtype)
print ('min,max,mean X_train: ',np.amin(X_train_pp_format),np.amax(X_train_pp_format), np.mean(X_train_pp_format))
print(X_test_pp_format.dtype)
print ('min,max,mean X_test: ',np.amin(X_test_pp_format),np.amax(X_test_pp_format), np.mean(X_test_pp_format))
print(X_valid_pp_format.dtype)
print ('min, max, mean X_valid: ', np.amin(X_valid_pp_format),np.amax(X_valid_pp_format), np.mean(X_valid_pp_format))
# Out:
# Number of training examples = 34799 number of training labels: 34799
# Number of testing examples = 12630 number of testing labels: 12630
# Number of validation examples = 12630 number of valid labels: 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43
# ---------------------------
# verify range of data -/+ 1
# float32
# min,max,mean X_train:  -1.02517 0.967015 6.24237e-08
# float32
# min,max,mean X_test:  -1.02813 0.964058 -2.25128e-08
# float32
# min, max, mean X_valid:  -1.02813 0.964058 -2.25128e-08

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# There is a German traffic sign dataset here:
# http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset#Downloads
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections.

# %%
### Data exploration visualization goes here.
### Feel free to use as many code cells as needed.


#plot histogram of classes/images for training. 
plt.hist(train['labels'], bins = n_classes)
plt.hist(test['labels'], bins= n_classes)
plt.hist(valid['labels'],bins= n_classes)
#this is awful. Poor distribution.
# Out:
# (array([  30.,  240.,  240.,  150.,  210.,  210.,   60.,  150.,  150.,
#          150.,  210.,  150.,  210.,  240.,   90.,   90.,   60.,  120.,
#          120.,   30.,   60.,   60.,   60.,   60.,   30.,  150.,   60.,
#           30.,   60.,   30.,   60.,   90.,   30.,   90.,   60.,  120.,
#           60.,   30.,  210.,   30.,   60.,   30.,   30.]),
#  array([  0.        ,   0.97674419,   1.95348837,   2.93023256,
#           3.90697674,   4.88372093,   5.86046512,   6.8372093 ,
#           7.81395349,   8.79069767,   9.76744186,  10.74418605,
#          11.72093023,  12.69767442,  13.6744186 ,  14.65116279,
#          15.62790698,  16.60465116,  17.58139535,  18.55813953,
#          19.53488372,  20.51162791,  21.48837209,  22.46511628,
#          23.44186047,  24.41860465,  25.39534884,  26.37209302,
#          27.34883721,  28.3255814 ,  29.30232558,  30.27906977,
#          31.25581395,  32.23255814,  33.20930233,  34.18604651,
#          35.1627907 ,  36.13953488,  37.11627907,  38.09302326,
#          39.06976744,  40.04651163,  41.02325581,  42.        ]),
#  <a list of 43 Patch objects>)

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.
#
# **NOTE:** The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!

# %% [markdown]
# ### Implementation
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %% [markdown]
# ### Question 1
#
# _Describe how you preprocessed the data. Why did you choose that technique?_

# %% [markdown]
# **Answer:**
#     1) color -> grayscale,
#     2) subtract mean of image set,
#     3) normalization to (+/-)1,
#     4) rotation +-15 degrees,
#     5) translation [-2,2] from lecture and paper
#
#     Histgram normalization from lecture in HSV space.
#     Measure effect on validation/test accuracy.
#     The new dataset (the one with the valid.p) was converted to semi-grayscale. This eliminates the rotation artifacts
#     which are dark black areas. Those can be interpreted as lines by the classifier.

# %%
### Generate additional data (OPTIONAL!)
### and split the data into training/validation/testing sets here.
### Feel free to use as many code cells as needed.

#additional data for classes which are low in training examples, rotate +-15 degrees, translate, histogram for darkness
#POINT: ndimage is awful. Use opencv
#POINT: we want a rotation wo the black edges after rotation which enlarges and shifts image
#images below show proof of artifacts and correction using warpTransform to unshift and shrink
#
from scipy import ndimage

def plotRot():
    img = O_train[0]
    

    rot = ndimage.rotate(img,15,reshape=True)

    print ("img.shape:",img.shape,"rotate shape:",rot.shape)
    blur=ndimage.gaussian_filter(rot,.5)
    print ('blur shape:', blur.shape)
    #CAREFUL THE CROP MOVES THE IMAGE and makes it bigger!!!
    #CAREFUL CROP uses gaussian blur output as starting point

    cols,rows=32,32
    rotAngle=15
    scaleFactor=.9 #expanded after crop
    M_plus = cv2.getRotationMatrix2D((cols/2,rows/2),rotAngle,scaleFactor)
    M_minus = cv2.getRotationMatrix2D((cols/2,rows/2),-rotAngle,scaleFactor)
    #32,32 is final destination size

    dst_plus = cv2.warpAffine(img,M_plus,(cols,rows))
    dst_minus = cv2.warpAffine(img,M_minus,(cols,rows))

    crop_plus = dst_plus[4:30,4:30]
    crop_minus = dst_minus[4:30,4:30]

    #we dont need this b/c the warpaffine gives a final size
    #dst_resize = cv2.resize(dst,(32,32))
    print('dst_plus shape:', dst_plus.shape)
    print('dst_minus shape:', dst_minus.shape)
    print('crop_plus shape:', crop_plus.shape)
    print('crop_minus shape:', crop_minus.shape)

    crop_plus_resize = cv2.resize(crop_plus,(32,32))
    crop_minus_resize = cv2.resize(crop_minus,(32,32))

    print ('crop_plus_resize shape:', crop_plus_resize.shape)
    print ('crop_plus_resize shape:', crop_minus_resize.shape)


    #there are a couple ways to draw figures in grids. I can never seem to remember them all and websearches are confusing
    #the easiest is 3 lines
    # fig = plt.figure
    # fig.add_subplot(1,7,1) which is 1 row with 7 columns adding first subplot for the last argument
    # plt.imshow(img)
    # easy to remember but painful to add more rows or columns cause you have to change all the constants
    # the second way is to use a plt.tight_layout
    #
    #
    # the third way is to use a gridspec

    gs1 = gridspec.GridSpec(5, 5)
    gs1.update(wspace=1.0, hspace=0.5) 
    plt.figure(figsize=(12,12))
    
    ax1 = plt.subplot(gs1[0])
    plt.subplot(5,5,1)
    plt.imshow(img)
    plt.title('orig')
    
    ax1 = plt.subplot(gs1[1])
    plt.subplot(5,5,2)
    plt.imshow(rot)
    plt.title('rot(ndimg)')
    
    ax1 = plt.subplot(gs1[2])
    plt.subplot(5,5,3)
    plt.imshow(blur)
    plt.title('blur')
    
    ax1 = plt.subplot(gs1[3])
    plt.subplot(5,5,4)
    plt.imshow(dst_plus)
    plt.title('dst_plus')
    
    ax1 = plt.subplot(gs1[4])
    plt.subplot(5,5,5)
    plt.imshow(dst_minus)
    plt.title('dst_min')
    
    ax1 = plt.subplot(gs1[5])
    plt.subplot(5,5,6)
    plt.imshow(crop_plus)
    plt.title('crop pls')
    
    ax1 = plt.subplot(gs1[6])
    plt.subplot(5,5,7)
    plt.imshow(crop_minus)
    plt.title('crop minus')
    
    ax1 = plt.subplot(gs1[7])
    plt.subplot(5,5,8)
    plt.imshow(crop_minus_resize)
    plt.title('cm resize')
    
    ax1 = plt.subplot(gs1[8])
    plt.subplot(5,5,9)
    plt.imshow(crop_plus_resize)
    plt.title('plus resize')

plotRot()    

#note: the crop_plus and crop_minus still look bigger than the original 
#this data is different; the black edge effects disappear w grayscale!!!
# Out:
# img.shape: (32, 32, 3) rotate shape: (39, 39, 3)
# blur shape: (39, 39, 3)
# dst_plus shape: (32, 32, 3)
# dst_minus shape: (32, 32, 3)
# crop_plus shape: (26, 26, 3)
# crop_minus shape: (26, 26, 3)
# crop_plus_resize shape: (32, 32, 3)
# crop_plus_resize shape: (32, 32, 3)

# %%
# use opencv. 
#better to convert these to grayscale before rotation
#scalefactor 3 gives .7 to 1.0 range. These are all smaller. Would bigger ones help? 
def rotImageCV(image, rotAngle, transFactor, scaleFactor):
   
    rows,cols,ch = image.shape
    #gray_image = rgb_gray(image)
    #M_plus = cv2.getRotationMatrix2D((cols/2,rows/2),randint(0,rotAngle),scaleFactor)
    M = cv2.getRotationMatrix2D((cols/2,rows/2),randint(-rotAngle,rotAngle),randint(10-scaleFactor,10)*.1)
    rotated_img = cv2.warpAffine(image,M,(cols,rows))
    shiftX = randint(-transFactor,transFactor)
    shiftY = randint(-transFactor,transFactor)
    M_translate = np.float32([[1,0,shiftX],[0,1,shiftY]])
    rot_trans_img = cv2.warpAffine(rotated_img,M_translate,(cols,rows))
    
    return rot_trans_img
    
    
def addData():
    numAdded = 0
    for i in range(0,43):
        for idx, img in enumerate (X_train):
            if (y_train[idx]==i):
                #if(idx%10==0):
                r = rotImageCV(img,15,5,3)
                orig.append(img)
                rot.append(r)
                labels.append(0)
                numAdded +=1
        
    print ('num rot, num labels',len(rot), len(labels))
    print ('numAdded:', numAdded)
    return orig, added

#plot some examples
gs1 = gridspec.GridSpec(3, 2)
#this spacing doesnt make a difference
gs1.update(wspace=2.0, hspace= 2.0)
plt.subplot(3,2,1)
plt.imshow(rot[10])

plt.subplot(3,2,2)
plt.imshow(rot[11])

plt.subplot(3,2,3)
plt.imshow(rot[12])

plt.subplot(3,2,4)
plt.imshow(rot[13])

plt.subplot(3,2,5)
plt.imshow(rot[14])


plt.subplot(3,2,6)
plt.imshow(rot[15])
# Out:
# num rot, num labels 34799 34799
# numAdded: 34799

# %%
#add rot[] to X_train, labels to y_train[]
#1) rot is a list convert to np array
#2) preprocess the rot to _pp then to pp_format
#3) verify min/max = +- 1 for preprocess. 
#Input: rot[], labels[]
#output X_train_rot_pp_format y_test_labels; make sure to set X_train and y_train to the output
rot_np=np.array(rot)
labels = np.array(labels)

print (rot_np.shape)
print('we dont care about rot_np, rot_np min, max, mean',np.amin(rot_np),np.amax(rot_np),np.mean(rot_np))
rot_pp = preprocess(rot_np,0)

print (rot_pp.shape)
print('rot_pp min, max, mean',np.amin(rot_pp),np.amax(rot_pp),np.mean(rot_pp))

rot_pp_format=rot_pp[...,newaxis]
print(rot_pp_format.shape)
print('rot_pp_format min, max, mean',np.amin(rot_pp_format),np.amax(rot_pp_format),np.mean(rot_pp_format))

#this is not formatted. Make sure you are consistent and appending labels AND new images at end. 
#this error is hard to debug cause you just get a crappy accuracy rate. 

print('before adding images X_train_pp shape',X_train_pp.shape, 'rot_pp shape:', rot_pp.shape)
print('before adding images y_train shape:', y_train.shape,' labels.shape', labels.shape)
X_train_rot_pp = np.concatenate((X_train_pp,rot_pp))
y_train_labels = np.concatenate((y_train,labels))


#fucked up the order!!! 
X_train_rot_pp_format=np.concatenate((X_train_pp_format,rot_pp_format))
print('X_train_rot_pp shape',X_train_rot_pp.shape)
print ('y_train_labels shape:', y_train_labels.shape)

gs1 = gridspec.GridSpec(3, 2)
#this spacing doesnt make a difference
gs1.update(wspace=2.0, hspace= 2.0)
plt.subplot(3,2,1)
plt.imshow(rot_pp[10],cmap='gray')

plt.subplot(3,2,2)
plt.imshow(rot_pp[11],cmap='gray')

plt.subplot(3,2,3)
plt.imshow(rot_pp[12],cmap='gray')

plt.subplot(3,2,4)
plt.imshow(rot_pp[13],cmap='gray')

plt.subplot(3,2,5)
plt.imshow(rot_pp[14],cmap='gray')


plt.subplot(3,2,6)
plt.imshow(rot_pp[15],cmap='gray')
# Out:
# (34799, 32, 32, 3)
# we dont care about rot_np, rot_np min, max, mean 0 255 54.8076630985
# (34799, 32, 32)
# rot_pp min, max, mean -0.350769 0.649231 6.88802e-09
# (34799, 32, 32, 1)
# rot_pp_format min, max, mean -0.350769 0.649231 6.88802e-09
# before adding images X_train_pp shape (34799, 32, 32) rot_pp shape: (34799, 32, 32)
# before adding images y_train shape: (34799,)  labels.shape (34799,)
# X_train_rot_pp shape (69598, 32, 32)
# y_train_labels shape: (69598,)

# %%
import matplotlib.gridspec as gridspec
import cv2
import matplotlib.image as mpimg

def augment_brightness_camera_images(image):
    image1 = cv2.cvtColor(image,cv2.COLOR_RGB2HSV)
    random_bright = .25+np.random.uniform()
    #print(random_bright)
    image1[:,:,2] = image1[:,:,2]*random_bright
    image1 = cv2.cvtColor(image1,cv2.COLOR_HSV2RGB)
    return image1

def transform_image(img,ang_range=20,shear_range=10,trans_range=5,brightness=0):
    '''
    This function transforms images to generate new images.
    The function takes in following arguments,
    1- Image
    2- ang_range: Range of angles for rotation
    3- shear_range: Range of values to apply affine transform to
    4- trans_range: Range of values to apply translations over.

    A Random uniform distribution is used to generate different parameters for transformation

    '''
    # Rotation
    ang_rot = np.random.uniform(ang_range)-ang_range/2
    rows,cols,ch = img.shape    
    Rot_M = cv2.getRotationMatrix2D((cols/2,rows/2),ang_rot,1)

    # Translation
    tr_x = trans_range*np.random.uniform()-trans_range/2
    tr_y = trans_range*np.random.uniform()-trans_range/2
    Trans_M = np.float32([[1,0,tr_x],[0,1,tr_y]])

    # Shear
    pts1 = np.float32([[5,5],[20,5],[5,20]])

    pt1 = 5+shear_range*np.random.uniform()-shear_range/2
    pt2 = 20+shear_range*np.random.uniform()-shear_range/2

    # Brightness
    pts2 = np.float32([[pt1,5],[pt2,pt1],[5,pt2]])

    shear_M = cv2.getAffineTransform(pts1,pts2)

    img = cv2.warpAffine(img,Rot_M,(cols,rows))
    img = cv2.warpAffine(img,Trans_M,(cols,rows))
    img = cv2.warpAffine(img,shear_M,(cols,rows))

    if brightness == 1:
      img = augment_brightness_camera_images(img)

    return img

# %% [markdown]
# ### Question 2
#
# _Describe how you set up the training, validation and testing data for your model. **Optional**: If you generated additional data, how did you generate the data? Why did you generate the data? What are the differences in the new dataset (with generated data) from the original dataset?_

# %% [markdown]
# **Answer:**
#     The dataset was changed from a train.p test.p to include a valid.p. This makes it easier to compare results. This changed the
#     code. Did not need the validation split using:
#     #shuffle before creating validation set.
#     X_train, y_train = shuffle(X_train, train['labels'])
#     print ("after shuffle X_train shape", X_train.shape, "y_train shape:", y_train.shape)
#
#     X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, stratify = y_train, test_size=.25, random_state=123)
#
#     Test Rotations: rotated +-15 degrees from the paper. The rotations using ndimage created black edges; used opencv to ger
#     of these artifacts. A rotataion translates and magnifies the image because we crop the image to remove the black edges.
#
#     The paper scales images from .9 to 1.1 and adds [-2,2] offset to the images.
#
#     View the test images to see what types of transformations are needed. Definitely brightness changes are required.

# %%
print (len(rot))
if len(rot)==0:
    X_train = X_train_pp_format
else:
    X_train=X_train_rot_pp_format  
    y_train = y_train_labels

#these should not be affected by adding data
X_test = X_test_pp_format
X_valid = X_valid_pp_format

print ('X_train shape:', X_train.shape, 'y_train shape:', y_train.shape)
print ('X_valid shape:',X_valid.shape, 'y_valid shape:', y_valid.shape)
print ('X_test shape:',X_test.shape, 'y_test shape', y_test.shape)
# Out:
# 0
# X_train shape: (34799, 32, 32, 1) y_train shape: (34799,)
# X_valid shape: (12630, 32, 32, 1) y_valid shape: (12630,)
# X_test shape: (12630, 32, 32, 1) y_test shape (12630,)

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.


#EPOCHS = 200
# adding more data requires more epochs
#EPOCHS= 30  #Test Accuracy = 0.972
EPOCHS = 10 #Test Accuracy = 0.922
BATCH_SIZE = 100
patch_size = 5
num_color = 1 
depth = 6

save_path = os.getcwd()+'/10EPOCHS.ckpt'
#save_path = os.getcwd() + '/30EPOCHS.ckpt'
#save_path = os.getcwd() + '/100EPOCHS.ckpt'

from tensorflow.contrib.layers import flatten


def LeNet(x):    
    # Arguments used for tf.truncated_normal, randomly defines variables for the weights and biases for each layer
    mu = 0
    sigma = 0.1
    
    # SOLUTION: Layer 1: Convolutional. Input = 32x32x1. Output = 28x28x6.
    conv1_W = tf.Variable(tf.truncated_normal(shape=(patch_size, patch_size, num_color, depth), mean = mu, stddev = sigma))
    conv1_b = tf.Variable(tf.zeros(depth))
    conv1   = tf.nn.conv2d(x, conv1_W, strides=[1, 1, 1, 1], padding='VALID') + conv1_b
    
    # SOLUTION: Activation.
    conv1 = tf.nn.relu(conv1)
    
    # SOLUTION: Pooling. Input = 28x28x6. Output = 14x14x6.
    conv1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')
    #tf.nn.dropout(conv1, .9)

    
    # SOLUTION: Layer 2: Convolutional. Output = 10x10x16.
    conv2_W = tf.Variable(tf.truncated_normal(shape=(5, 5, 6, 16), mean = mu, stddev = sigma))
    conv2_b = tf.Variable(tf.zeros(16))
    conv2   = tf.nn.conv2d(conv1, conv2_W, strides=[1, 1, 1, 1], padding='VALID') + conv2_b
    
    # SOLUTION: Activation.
    conv2 = tf.nn.relu(conv2)
    #tf.nn.dropout(conv2, .7)

    
    # SOLUTION: Pooling. Input = 10x10x16. Output = 5x5x16.
    conv2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')
    
    flat = tf.contrib.layers.flatten(conv2)
    
    # SOLUTION: Layer 3: Fully Connected. Input = 400. Output = 120.
    fc1_W = tf.Variable(tf.truncated_normal(shape=(400, 200), mean = mu, stddev = sigma))
    fc1_b = tf.Variable(tf.zeros(200))
    fc1   = tf.matmul(flat, fc1_W) + fc1_b
    
    
    # SOLUTION: Activation.
    fc1    = tf.nn.relu(fc1)
    h_fc1_drop = tf.nn.dropout(fc1, keep_prob)
    
    # SOLUTION: Layer 4: Fully Connected. Input = 120. Output = 84.
    fc2_W  = tf.Variable(tf.truncated_normal(shape=(200, 100), mean = mu, stddev = sigma))
    fc2_b  = tf.Variable(tf.zeros(100))
    fc2    = tf.matmul(h_fc1_drop, fc2_W) + fc2_b
    
    # SOLUTION: Activation.
    fc2    = tf.nn.relu(fc2)
    #print ("after relu fc2 shape:", fc2.get_shape())
    
    h_fc2_drop = tf.nn.dropout(fc2, keep_prob)
    
    # SOLUTION: Layer 5: Fully Connected. Input = 84. Output = 43.
    fc3_W  = tf.Variable(tf.truncated_normal(shape=(100, 43), mean = mu, stddev = sigma))
    fc3_b  = tf.Variable(tf.zeros(43))
    logits = tf.matmul(h_fc2_drop, fc3_W) + fc3_b
    
    print ('logits shape:',logits.get_shape())
    return logits

# %%
#set variables x is X_train or input training images, y is y_train or labels

x = tf.placeholder(tf.float32, (None, 32, 32, 1))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)
#dropout from tf mnist webpage https://www.tensorflow.org/get_started/mnist/pros
keep_prob = tf.placeholder(tf.float32)

# %%
rate = 0.001

logits = LeNet(x)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
#cost = tf.reduce_mean(cross_entropy)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y))
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)
# Out:
# logits shape: (?, 43)

# %%
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
saver = tf.train.Saver()


def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    total_loss = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        loss, accuracy = sess.run([loss_operation,accuracy_operation], feed_dict={x: batch_x, y: batch_y, keep_prob: 1.0})
        total_accuracy += (accuracy * len(batch_x))
        total_loss += (loss * len(batch_x))
    return total_loss/num_examples , total_accuracy / num_examples

# %%
from sklearn.utils import shuffle

#print ('X_train_pp_format shape:', X_train_pp_format.shape)
    #X_train = X_train_pp_format

print ('X_train shape', X_train.shape, 'y_train shape', y_train.shape)
print ('X_test shape', X_test.shape, 'y_test shape:', y_test.shape)
print('X_valid shape:', X_valid.shape, 'y_valid shape:', y_valid.shape)
print ('logits shape:', logits.get_shape())
   
# we should shuffle data in runModel
init_op = tf.global_variables_initializer()
#diff tf.initialize_all_variables()
print ("init_op set globally")        

def runModel(X_train,y_train,X_valid,y_valid, init_graph):
    '''
    '''
    X_train, y_train = shuffle(X_train, y_train)
    
    valid_loss = []
    valid_acc = []
    
    with tf.Session() as sess:
        sess.run(init_op)
        num_examples = len(X_train)
        print ('num_examples', num_examples)
        print("Training...")
        
        for i in range(EPOCHS):
            X_train, y_train = shuffle(X_train, y_train)
            for offset in range(0, num_examples, BATCH_SIZE):
                end = offset + BATCH_SIZE
                #print ('offset:', offset, 'end:',end)
                batch_x, batch_y = X_train[offset:end], y_train[offset:end]
                #print ('batch_x shape:',batch_x.shape,' batch_y.shape', batch_y.shape)
                loss = sess.run(training_operation, feed_dict={x: batch_x, y: batch_y,keep_prob: 0.5})
                # add batch normalization
                
                
                
            #batch_loss, batch_accuracy = evaluate(batch_x,batch_y)
            #print("batch Accuracy = {:.3f}".format(batch_accuracy))
            validation_loss, validation_accuracy = evaluate(X_valid, y_valid)
            valid_acc.append(validation_accuracy)
            valid_loss.append(validation_loss)
           
            print("EPOCH {} ...".format(i+1))
            print("Validation Accuracy = {:.3f}".format(validation_accuracy))
            #valid_acc.append(validation_accuracy)
            #print_epoch_stats(i,sess,batch_x, batch_y)
            print()
        
        saver.save(sess, save_path)
        print("Model saved")
        return valid_loss, valid_acc

    
valid_loss,valid_acc = runModel(X_train,y_train,X_valid,y_valid, init_op)
# Out:
# X_train shape (34799, 32, 32, 1) y_train shape (34799,)
# X_test shape (12630, 32, 32, 1) y_test shape: (12630,)
# X_valid shape: (12630, 32, 32, 1) y_valid shape: (12630,)
# logits shape: (?, 43)
# init_op set globally
# num_examples 34799
# Training...
# EPOCH 1 ...
# Validation Accuracy = 0.741
#
# EPOCH 2 ...
# Validation Accuracy = 0.835
#
# EPOCH 3 ...
# Validation Accuracy = 0.886
#
# EPOCH 4 ...
# Validation Accuracy = 0.892
#
# EPOCH 5 ...
# Validation Accuracy = 0.907
#
# EPOCH 6 ...
# Validation Accuracy = 0.917
#
# EPOCH 7 ...
# Validation Accuracy = 0.920
#
# EPOCH 8 ...
# Validation Accuracy = 0.921
#
# EPOCH 9 ...
# Validation Accuracy = 0.923
#
# EPOCH 10 ...
# Validation Accuracy = 0.930
#
# Model saved

# %%
# 30 epochs 3480 added data 
plt.plot(valid_loss)
plt.ylabel('loss')
plt.show()

# %%
# addition of 3480 data, every 10th sample generate one rotated/trans image
# 10 epochs; this model should be stopped after 7 epochs. This graph looks like what is in the 
# slides. 
plt.plot(valid_loss)
plt.ylabel('loss')
plt.show()

# %%
# no addition of data, 10 epochs
plt.plot(valid_loss)
plt.ylabel('loss')
plt.show()

# %%
plt.plot(valid_acc)
plt.ylabel('acc')
plt.show()

# %%
###We can see the loss accuracy decrease till .541 then it increases. This is the validation accuracy and not the Loss. 
###This was run on a TitanX. At .541 we have run 98 epochs. 
batch Accuracy = 0.572
EPOCH 1 ...
Validation Accuracy = 0.542

batch Accuracy = 0.839
EPOCH 2 ...
Validation Accuracy = 0.754

batch Accuracy = 0.916
EPOCH 3 ...
Validation Accuracy = 0.822

batch Accuracy = 0.936
EPOCH 4 ...
Validation Accuracy = 0.860

batch Accuracy = 0.973
EPOCH 5 ...
Validation Accuracy = 0.874

batch Accuracy = 0.960
EPOCH 6 ...
Validation Accuracy = 0.885

batch Accuracy = 0.967
EPOCH 7 ...
Validation Accuracy = 0.901

batch Accuracy = 0.973
EPOCH 8 ...
Validation Accuracy = 0.906

batch Accuracy = 0.990
EPOCH 9 ...
Validation Accuracy = 0.912

batch Accuracy = 0.980
EPOCH 10 ...
Validation Accuracy = 0.917

batch Accuracy = 0.973
EPOCH 11 ...
Validation Accuracy = 0.918

batch Accuracy = 0.990
EPOCH 12 ...
Validation Accuracy = 0.923

batch Accuracy = 0.983
EPOCH 13 ...
Validation Accuracy = 0.925

batch Accuracy = 0.983
EPOCH 14 ...
Validation Accuracy = 0.927

batch Accuracy = 0.993
EPOCH 15 ...
Validation Accuracy = 0.925

batch Accuracy = 0.983
EPOCH 16 ...
Validation Accuracy = 0.927

batch Accuracy = 0.983
EPOCH 17 ...
Validation Accuracy = 0.929

batch Accuracy = 1.000
EPOCH 18 ...
Validation Accuracy = 0.934

batch Accuracy = 0.990
EPOCH 19 ...
Validation Accuracy = 0.928

batch Accuracy = 0.993
EPOCH 20 ...
Validation Accuracy = 0.934

batch Accuracy = 0.990
EPOCH 21 ...
Validation Accuracy = 0.934

batch Accuracy = 0.997
EPOCH 22 ...
Validation Accuracy = 0.933

batch Accuracy = 1.000
EPOCH 23 ...
Validation Accuracy = 0.933

batch Accuracy = 0.993
EPOCH 24 ...
Validation Accuracy = 0.936

batch Accuracy = 0.993
EPOCH 25 ...
Validation Accuracy = 0.930

batch Accuracy = 0.997
EPOCH 26 ...
Validation Accuracy = 0.935

batch Accuracy = 0.997
EPOCH 27 ...
Validation Accuracy = 0.940

batch Accuracy = 1.000
EPOCH 28 ...
Validation Accuracy = 0.936

batch Accuracy = 0.997
EPOCH 29 ...
Validation Accuracy = 0.936

batch Accuracy = 0.997
EPOCH 30 ...
Validation Accuracy = 0.938

batch Accuracy = 1.000
EPOCH 31 ...
Validation Accuracy = 0.940

batch Accuracy = 1.000
EPOCH 32 ...
Validation Accuracy = 0.939

batch Accuracy = 0.993
EPOCH 33 ...
Validation Accuracy = 0.940

batch Accuracy = 1.000
EPOCH 34 ...
Validation Accuracy = 0.941

batch Accuracy = 0.997
EPOCH 35 ...
Validation Accuracy = 0.943

batch Accuracy = 1.000
EPOCH 36 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 37 ...
Validation Accuracy = 0.943

batch Accuracy = 0.997
EPOCH 38 ...
Validation Accuracy = 0.943

batch Accuracy = 1.000
EPOCH 39 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 40 ...
Validation Accuracy = 0.944

batch Accuracy = 1.000
EPOCH 41 ...
Validation Accuracy = 0.942

batch Accuracy = 0.997
EPOCH 42 ...
Validation Accuracy = 0.940

batch Accuracy = 0.997
EPOCH 43 ...
Validation Accuracy = 0.943

batch Accuracy = 0.997
EPOCH 44 ...
Validation Accuracy = 0.942

batch Accuracy = 0.997
EPOCH 45 ...
Validation Accuracy = 0.943

batch Accuracy = 0.990
EPOCH 46 ...
Validation Accuracy = 0.943

batch Accuracy = 0.997
EPOCH 47 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 48 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 49 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 50 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 51 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 52 ...
Validation Accuracy = 0.943

batch Accuracy = 1.000
EPOCH 53 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 54 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 55 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 56 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 57 ...
Validation Accuracy = 0.944

batch Accuracy = 1.000
EPOCH 58 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 59 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 60 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 61 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 62 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 63 ...
Validation Accuracy = 0.946

batch Accuracy = 0.997
EPOCH 64 ...
Validation Accuracy = 0.943

batch Accuracy = 1.000
EPOCH 65 ...
Validation Accuracy = 0.946

batch Accuracy = 0.997
EPOCH 66 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 67 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 68 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 69 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 70 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 71 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 72 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 73 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 74 ...
Validation Accuracy = 0.944

batch Accuracy = 0.997
EPOCH 75 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 76 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 77 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 78 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 79 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 80 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 81 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 82 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 83 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 84 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 85 ...
Validation Accuracy = 0.944

batch Accuracy = 1.000
EPOCH 86 ...
Validation Accuracy = 0.947

batch Accuracy = 0.997
EPOCH 87 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 88 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 89 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 90 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 91 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 92 ...
Validation Accuracy = 0.944

batch Accuracy = 0.997
EPOCH 93 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 94 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 95 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 96 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 97 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 98 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 99 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 100 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 101 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 102 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 103 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 104 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 105 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 106 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 107 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 108 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 109 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 110 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 111 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 112 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 113 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 114 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 115 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 116 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 117 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 118 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 119 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 120 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 121 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 122 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 123 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 124 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 125 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 126 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 127 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 128 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 129 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 130 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 131 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 132 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 133 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 134 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 135 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 136 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 137 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 138 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 139 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 140 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 141 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 142 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 143 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 144 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 145 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 146 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 147 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 148 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 149 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 150 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 151 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 152 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 153 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 154 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 155 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 156 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 157 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 158 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 159 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 160 ...
Validation Accuracy = 0.953

batch Accuracy = 1.000
EPOCH 161 ...
Validation Accuracy = 0.953

batch Accuracy = 1.000
EPOCH 162 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 163 ...
Validation Accuracy = 0.953

batch Accuracy = 1.000
EPOCH 164 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 165 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 166 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 167 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 168 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 169 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 170 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 171 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 172 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 173 ...
Validation Accuracy = 0.954

batch Accuracy = 1.000
EPOCH 174 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 175 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 176 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 177 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 178 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 179 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 180 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 181 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 182 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 183 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 184 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 185 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 186 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 187 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 188 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 189 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 190 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 191 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 192 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 193 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 194 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 195 ...
Validation Accuracy = 0.953

batch Accuracy = 1.000
EPOCH 196 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 197 ...
Validation Accuracy = 0.953

batch Accuracy = 1.000
EPOCH 198 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 199 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 200 ...
Validation Accuracy = 0.952

Model saved
Out[31]:
0.95225658750873843

# %%
# run an ensemble of models say 10 and calculate the mean/std deviation from these
# run this in the titanX
ten_acc = []
ten_loss = []
for idx in xrange(10):
    #should work wo mods since we only return validation_accuracy
    titanX_loss, titanX_acc = runModel(X_train,y_train,X_valid,y_valid)
    ten_acc.append(titanX_acc)
    ten_loss.append(titaX_loss)

with open('loss.txt', 'w') as lossfile:
    pickle.dump(ten_loss,lossfile)
with open('acc.txt', 'w') as accfile:
    pickle.dump(acc_loss, accfile)

# %% [markdown]
# ### Question 3
#
# _What does your final architecture look like? (Type of model, layers, sizes, connectivity, etc.)  For reference on how to build a deep neural network using TensorFlow, see [Deep Neural Network in TensorFlow
# ](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/b516a270-8600-4f93-a0a3-20dfeabe5da6/concepts/83a3a2a2-a9bd-4b7b-95b0-eb924ab14432) from the classroom._

# %% [markdown]
# **Answer:**
#     1) copied lenet architecture for MNIST, added dropout using paper.
#     Layers+ Sizes:
#         1) ConvLayer1: 32x32x1
#         2) ConvLayer2: 14x14x6
#         3) FC1: 400
#         4) FC2: 120
#         5) FC3: 84

# %%
#difference between latest checkpoint and save? 
with tf.Session() as sess:
    saver.restore(sess, save_path)

    test_loss, test_accuracy = evaluate(X_test, y_test)
    print("Test Accuracy = {:.3f}".format(test_accuracy))
# Out:
# Test Accuracy = 0.935

# %% [markdown]
# ### Question 4
#
# _How did you train your model? (Type of optimizer, batch size, epochs, hyperparameters, etc.)_

# %%
**Answer:** Adam Optimizer. 
    number of training examples = batch_size*#epochs
    hyperparamters: 
    
    Experiment: Disclaimer(This has nothing to do with our data): 
    30 samples in validation set is Satistically Significant. Lecture 26 Intro to TF
    if 3000 examples in validation set, 1%*3000/100=30 examples. So 1% accuarte. 
    7842*x%/100=30 examples; x=3000/7842=.38. Accurate to ~99%-.4=98.6. Is this a correct statement?
    
    
    https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf
    Adam Optimizer
    Batch Size: 100
    Epochs: 10 for experiment run on MacBook when I need result
    Epochs: 100 run in TitanX plot Validation Accuracy as it improves then increases. Use this as an approximation
    to the rising loss curve.

# %% [markdown]
# ### Question 5
#
#
# _What approach did you take in coming up with a solution to this problem? It may have been a process of trial and error, in which case, outline the steps you took to get to the final solution and why you chose those steps. Perhaps your solution involved an already well known implementation or architecture. In this case, discuss why you think this is suitable for the current problem._

# %%
**Answer:**
    Started with LeNet architecture. Trial and error to get something working
    Hyperparameter tuning: 
    Step 1) Implemented improvements from lecture including dropout. 
    Step 2) When tuning hyperparameters; run 10 and compare the mean/std deviation assuming Normal distribution. Use 
    the test set to compare loss error for hyperparameter tuning.

# %%
### Error Analysis
Document where the errors are occurring. In what class and see if adding more augmentation helps

# %%
### Run the predictions here.
### Feel free to use as many code cells as needed.

#testMe=[]
# you should be able to put the whole array here!!!
#X_test_pp_format or X_valid_pp_format into the feed_dict
#testMe.append(X_test_pp_format[0])
#T_test=np.array(testMe)
#print('T_test shape:',T_test.shape)

with tf.Session() as sess:
    saver.restore(sess, save_path )
    softmax = tf.nn.softmax(logits)
    top_k_val, top_k_idx = tf.nn.top_k(softmax, k=5)
    
    #top_k_vals, top_k_idxs = sess.run([top_k_val, top_k_idx], feed_dict={x: T_test, keep_prob : 1.0})
    top_k_vals, top_k_idxs = sess.run([top_k_val, top_k_idx], feed_dict={x: X_test_pp_format, keep_prob : 1.0})

# %%
#run after X_test_pp_format
print (top_k_val.get_shape())
print (top_k_idxs.shape)
print (top_k_idx[0].get_shape())
print ("test image 0 is:", y_test[0])
tmp = top_k_idxs.shape[0]
print ('tmp:',tmp)
numHit=[]
for y in range(top_k_idxs.shape[0]):
    for x in range(len(top_k_idxs[0])):
        #print ('x:',x, 'y:',y)
        if(x==0 and (y_test[y]!=top_k_idxs[y][x])):
            print ('Mismatch..' ,(x,y))
            numHit.append((x,y))
        if x==0:
            print ('prob:', top_k_vals[y][x],' class:',top_k_idxs[y][x], 'y_test:',y_test[y])
        else:
            print ('     prob:', top_k_vals[y][x],' class:',top_k_idxs[y][x], 'y_test:',y_test[y])
    
print (len(numHit)) #855 no match in test set
# Out:
# (?, 5)
# (12630, 5)
# (5,)
# test image 0 is: 16
# tmp: 12630
# prob: 0.994568  class: 16 y_test: 16
#      prob: 0.00536912  class: 9 y_test: 16
#      prob: 2.64596e-05  class: 7 y_test: 16
#      prob: 2.27779e-05  class: 10 y_test: 16
#      prob: 1.1028e-05  class: 40 y_test: 16
# prob: 0.999979  class: 1 y_test: 1
#      prob: 2.04205e-05  class: 0 y_test: 1
#      prob: 2.62286e-07  class: 6 y_test: 1
#      prob: 1.56166e-07  class: 2 y_test: 1
#      prob: 1.05772e-07  class: 5 y_test: 1
# prob: 1.0  class: 38 y_test: 38
#      prob: 2.50454e-12  class: 34 y_test: 38
#      prob: 5.78722e-17  class: 36 y_test: 38
#      prob: 3.36816e-17  class: 14 y_test: 38
#      prob: 3.28205e-17  class: 40 y_test: 38
# prob: 0.999997  class: 33 y_test: 33
#      prob: 1.43913e-06  class: 17 y_test: 33
#      prob: 7.96081e-07  class: 39 y_test: 33
#      prob: 8.62795e-08  class: 37 y_test: 33
#      prob: 6.75096e-08  class: 35 y_test: 33
# prob: 1.0  class: 11 y_test: 11
#      prob: 2.18338e-07  class: 30 y_test: 11
#      prob: 7.78589e-09  class: 21 y_test: 11
#      prob: 1.43877e-10  class: 27 y_test: 11
#      prob: 1.72593e-11  class: 40 y_test: 11
# prob: 1.0  class: 38 y_test: 38
#      prob: 1.36801e-11  class: 34 y_test: 38
#      prob: 8.69763e-16  class: 36 y_test: 38
#      prob: 1.84475e-16  class: 14 y_test: 38
#      prob: 2.13551e-17  class: 13 y_test: 38
# prob: 0.999854  class: 18 y_test: 18
#      prob: 9.73296e-05  class: 26 y_test: 18
#      prob: 4.75897e-05  class: 27 y_test: 18
#      prob: 6.28875e-07  class: 24 y_test: 18
#      prob: 9.32654e-10  class: 28 y_test: 18
# prob: 1.0  class: 12 y_test: 12
#      prob: 1.80594e-09  class: 40 y_test: 12
#      prob: 1.14356e-09  class: 8 y_test: 12
#      prob: 9.90746e-10  class: 7 y_test: 12
#      prob: 7.5302e-13  class: 17 y_test: 12
# prob: 1.0  class: 25 y_test: 25
#      prob: 2.48905e-10  class: 20 y_test: 25
#      prob: 2.70926e-12  class: 22 y_test: 25
#      prob: 8.57588e-13  class: 29 y_test: 25
#      prob: 2.62425e-14  class: 23 y_test: 25
# prob: 1.0  class: 35 y_test: 35
#      prob: 1.51754e-08  class: 33 y_test: 35
#      prob: 9.68844e-11  class: 3 y_test: 35
#      prob: 6.04117e-11  class: 34 y_test: 35
#      prob: 1.53638e-11  class: 10 y_test: 35
# prob: 0.999091  class: 12 y_test: 12
#      prob: 0.000762118  class: 40 y_test: 12
#      prob: 5.30129e-05  class: 42 y_test: 12
#      prob: 4.99625e-05  class: 11 y_test: 12
#      prob: 3.69135e-05  class: 7 y_test: 12
# prob: 0.98731  class: 7 y_test: 7
#      prob: 0.0126409  class: 8 y_test: 7
#      prob: 3.43234e-05  class: 5 y_test: 7
#      prob: 1.17948e-05  class: 2 y_test: 7
#      prob: 2.66282e-06  class: 4 y_test: 7
# prob: 0.99043  class: 23 y_test: 23
#      prob: 0.00895843  class: 19 y_test: 23
#      prob: 0.000495999  class: 21 y_test: 23
#      prob: 3.63012e-05  class: 31 y_test: 23
#      prob: 3.41341e-05  class: 30 y_test: 23
# prob: 0.979579  class: 7 y_test: 7
#      prob: 0.00824474  class: 8 y_test: 7
#      prob: 0.00808104  class: 5 y_test: 7
#      prob: 0.00249249  class: 40 y_test: 7
#      prob: 0.00106663  class: 2 y_test: 7
# prob: 0.77207  class: 4 y_test: 4
#      prob: 0.227136  class: 1 y_test: 4
#      prob: 0.000501905  class: 0 y_test: 4
#      prob: 0.000138272  class: 2 y_test: 4
#      prob: 0.000138069  class: 5 y_test: 4
# prob: 0.997617  class: 9 y_test: 9
#      prob: 0.00180589  class: 10 y_test: 9
#      prob: 0.000282648  class: 3 y_test: 9
#      prob: 0.000137874  class: 16 y_test: 9
#      prob: 8.25312e-05  class: 15 y_test: 9
# prob: 0.817223  class: 21 y_test: 21
#      prob: 0.176262  class: 31 y_test: 21
#      prob: 0.00398341  class: 23 y_test: 21
#      prob: 0.00253165  class: 19 y_test: 21
#      prob: 1.49831e-08  class: 30 y_test: 21
# prob: 0.870816  class: 20 y_test: 20
#      prob: 0.121063  class: 28 y_test: 20
#      prob: 0.00230166  class: 30 y_test: 20
#      prob: 0.00189021  class: 23 y_test: 20
#      prob: 0.00129364  class: 25 y_test: 20
# prob: 0.690954  class: 27 y_test: 27
#      prob: 0.205357  class: 18 y_test: 27
#      prob: 0.0532812  class: 24 y_test: 27
#      prob: 0.0207341  class: 11 y_test: 27
#      prob: 0.00713694  class: 28 y_test: 27
# prob: 1.0  class: 38 y_test: 38
#      prob: 1.99145e-11  class: 34 y_test: 38
#      prob: 9.49603e-15  class: 14 y_test: 38
#      prob: 1.0844e-16  class: 36 y_test: 38
#      prob: 3.66126e-18  class: 13 y_test: 38
# prob: 0.99964  class: 4 y_test: 4
#      prob: 0.000328457  class: 1 y_test: 4
#      prob: 1.81168e-05  class: 0 y_test: 4
#      prob: 8.90664e-06  class: 8 y_test: 4
#      prob: 3.15579e-06  class: 2 y_test: 4
# prob: 1.0  class: 33 y_test: 33
#      prob: 7.65464e-08  class: 39 y_test: 33
#      prob: 3.00156e-11  class: 37 y_test: 33
#      prob: 1.30431e-11  class: 35 y_test: 33
#      prob: 2.16073e-13  class: 14 y_test: 33
# prob: 1.0  class: 9 y_test: 9
#      prob: 4.17094e-10  class: 16 y_test: 9
#      prob: 8.26287e-12  class: 10 y_test: 9
#      prob: 2.15855e-12  class: 12 y_test: 9
#      prob: 1.10982e-14  class: 23 y_test: 9
# prob: 0.548634  class: 3 y_test: 3
#      prob: 0.445265  class: 5 y_test: 3
#      prob: 0.00313212  class: 1 y_test: 3
#      prob: 0.00114648  class: 6 y_test: 3
#      prob: 0.000945733  class: 2 y_test: 3
# prob: 1.0  class: 1 y_test: 1
#      prob: 2.72066e-07  class: 0 y_test: 1
#      prob: 1.7669e-07  class: 2 y_test: 1
#      prob: 1.55771e-08  class: 5 y_test: 1
#      prob: 7.41088e-10  class: 4 y_test: 1
# prob: 0.999263  class: 11 y_test: 11
#      prob: 0.000725171  class: 30 y_test: 11
#      prob: 8.07433e-06  class: 27 y_test: 11
#      prob: 1.9327e-06  class: 40 y_test: 11
#      prob: 5.55346e-07  class: 23 y_test: 11
# prob: 1.0  class: 13 y_test: 13
#      prob: 7.41328e-10  class: 12 y_test: 13
#      prob: 5.91154e-11  class: 35 y_test: 13
#      prob: 4.92026e-11  class: 15 y_test: 13
#      prob: 2.0597e-11  class: 38 y_test: 13
# prob: 0.999994  class: 10 y_test: 10
#      prob: 3.25585e-06  class: 9 y_test: 10
#      prob: 2.75906e-06  class: 5 y_test: 10
#      prob: 4.3858e-07  class: 7 y_test: 10
#      prob: 4.62133e-08  class: 23 y_test: 10
# prob: 0.999329  class: 9 y_test: 9
#      prob: 0.000670251  class: 10 y_test: 9
#      prob: 7.52074e-07  class: 16 y_test: 9
#      prob: 6.88066e-08  class: 23 y_test: 9
#      prob: 2.87699e-08  class: 7 y_test: 9
# prob: 0.999966  class: 11 y_test: 11
#      prob: 1.235e-05  class: 21 y_test: 11
#      prob: 1.0249e-05  class: 27 y_test: 11
#      prob: 9.01224e-06  class: 30 y_test: 11
#      prob: 1.20486e-06  class: 23 y_test: 11
# prob: 0.989595  class: 5 y_test: 5
#      prob: 0.0103023  class: 3 y_test: 5
#      prob: 9.53784e-05  class: 2 y_test: 5
#      prob: 6.30893e-06  class: 10 y_test: 5
#      prob: 1.12522e-06  class: 7 y_test: 5
# prob: 1.0  class: 17 y_test: 17
#      prob: 1.19103e-09  class: 14 y_test: 17
#      prob: 2.24685e-14  class: 33 y_test: 17
#      prob: 9.46175e-15  class: 40 y_test: 17
#      prob: 7.33841e-16  class: 34 y_test: 17
# prob: 0.999958  class: 34 y_test: 34
#      prob: 3.4184e-05  class: 38 y_test: 34
#      prob: 2.56903e-06  class: 35 y_test: 34
#      prob: 2.26863e-06  class: 14 y_test: 34
#      prob: 1.35663e-06  class: 12 y_test: 34
# prob: 0.889925  class: 23 y_test: 23
#      prob: 0.0806099  class: 19 y_test: 23
#      prob: 0.00997121  class: 30 y_test: 23
#      prob: 0.00760954  class: 21 y_test: 23
#      prob: 0.00574214  class: 11 y_test: 23
# prob: 1.0  class: 2 y_test: 2
#      prob: 6.85243e-09  class: 5 y_test: 2
#      prob: 2.29588e-10  class: 7 y_test: 2
#      prob: 2.22001e-10  class: 1 y_test: 2
#      prob: 1.92371e-10  class: 3 y_test: 2
# prob: 0.999931  class: 17 y_test: 17
#      prob: 6.8966e-05  class: 14 y_test: 17
#      prob: 3.11359e-08  class: 33 y_test: 17
#      prob: 2.23706e-08  class: 40 y_test: 17
#      prob: 5.55438e-09  class: 37 y_test: 17
# prob: 0.999803  class: 3 y_test: 3
#      prob: 0.000196361  class: 5 y_test: 3
#      prob: 1.61364e-07  class: 2 y_test: 3
#      prob: 1.54173e-09  class: 16 y_test: 3
#      prob: 1.40725e-09  class: 1 y_test: 3
# prob: 0.999471  class: 12 y_test: 12
#      prob: 0.000494573  class: 40 y_test: 12
#      prob: 2.13367e-05  class: 7 y_test: 12
#      prob: 4.68614e-06  class: 11 y_test: 12
#      prob: 3.68101e-06  class: 17 y_test: 12
# prob: 0.999974  class: 16 y_test: 16
#      prob: 1.83018e-05  class: 9 y_test: 16
#      prob: 7.83908e-06  class: 3 y_test: 16
#      prob: 6.18723e-08  class: 40 y_test: 16
#      prob: 3.2453e-08  class: 7 y_test: 16
# prob: 0.646372  class: 8 y_test: 8
#      prob: 0.229177  class: 7 y_test: 8
#      prob: 0.0566523  class: 15 y_test: 8
#      prob: 0.0425149  class: 4 y_test: 8
#      prob: 0.0106296  class: 5 y_test: 8
# prob: 0.999808  class: 7 y_test: 7
#      prob: 0.000113044  class: 40 y_test: 7
#      prob: 5.67796e-05  class: 8 y_test: 7
#      prob: 1.59849e-05  class: 5 y_test: 7
#      prob: 4.31315e-06  class: 2 y_test: 7
# prob: 0.530483  class: 30 y_test: 30
#      prob: 0.29754  class: 23 y_test: 30
#      prob: 0.136217  class: 31 y_test: 30
#      prob: 0.0178395  class: 21 y_test: 30
#      prob: 0.00686393  class: 29 y_test: 30
# prob: 0.992249  class: 18 y_test: 18
#      prob: 0.0062853  class: 26 y_test: 18
#      prob: 0.00134974  class: 27 y_test: 18
#      prob: 0.000114307  class: 24 y_test: 18
#      prob: 1.13889e-06  class: 28 y_test: 18
# prob: 1.0  class: 12 y_test: 12
#      prob: 9.7191e-08  class: 40 y_test: 12
#      prob: 8.27643e-09  class: 7 y_test: 12
#      prob: 3.20195e-11  class: 11 y_test: 12
#      prob: 5.59187e-12  class: 42 y_test: 12
# prob: 0.501216  class: 24 y_test: 24
#      prob: 0.211517  class: 27 y_test: 24
#      prob: 0.0876531  class: 30 y_test: 24
#      prob: 0.0648445  class: 20 y_test: 24
#      prob: 0.0476102  class: 28 y_test: 24
# prob: 0.999822  class: 25 y_test: 25
#      prob: 0.000115089  class: 20 y_test: 25
#      prob: 2.33246e-05  class: 22 y_test: 25
#      prob: 1.37516e-05  class: 30 y_test: 25
#      prob: 1.03539e-05  class: 29 y_test: 25
# prob: 0.999614  class: 3 y_test: 3
#      prob: 0.000385753  class: 5 y_test: 3
#      prob: 2.84482e-09  class: 2 y_test: 3
#      prob: 2.6874e-11  class: 7 y_test: 3
#      prob: 5.84531e-12  class: 16 y_test: 3
# prob: 0.999807  class: 10 y_test: 10
#      prob: 0.000192668  class: 9 y_test: 10
#      prob: 5.43027e-12  class: 5 y_test: 10
#      prob: 1.94408e-13  class: 7 y_test: 10
#      prob: 2.52274e-14  class: 23 y_test: 10
# prob: 0.27346  class: 18 y_test: 18
#      prob: 0.20227  class: 31 y_test: 18
#      prob: 0.105392  class: 26 y_test: 18
#      prob: 0.0514106  class: 21 y_test: 18
#      prob: 0.0499617  class: 40 y_test: 18
# HIT (0, 49)
# prob: 0.50454  class: 38 y_test: 8
#      prob: 0.197918  class: 1 y_test: 8
#      prob: 0.165465  class: 0 y_test: 8
#      prob: 0.0893936  class: 14 y_test: 8
#      prob: 0.0192599  class: 4 y_test: 8
# HIT (0, 50)
# prob: 0.516918  class: 4 y_test: 25
#      prob: 0.101368  class: 1 y_test: 25
#      prob: 0.0686  class: 39 y_test: 25
#      prob: 0.0651535  class: 2 y_test: 25
#      prob: 0.0497895  class: 18 y_test: 25
# prob: 1.0  class: 13 y_test: 13
#      prob: 7.13539e-08  class: 12 y_test: 13
#      prob: 1.0523e-08  class: 38 y_test: 13
#      prob: 2.71503e-10  class: 15 y_test: 13
#      prob: 2.71077e-10  class: 9 y_test: 13
# prob: 0.974864  class: 15 y_test: 15
#      prob: 0.0215655  class: 8 y_test: 15
#      prob: 0.00327426  class: 4 y_test: 15
#      prob: 0.000109398  class: 5 y_test: 15
#      prob: 0.000109151  class: 3 y_test: 15
# prob: 0.999997  class: 9 y_test: 9
#      prob: 3.12258e-06  class: 10 y_test: 9
#      prob: 1.55394e-12  class: 16 y_test: 9
#      prob: 2.56805e-13  class: 23 y_test: 9
#      prob: 2.50983e-14  class: 3 y_test: 9
# prob: 1.0  class: 13 y_test: 13
#      prob: 4.97115e-10  class: 15 y_test: 13
#      prob: 1.82292e-10  class: 12 y_test: 13
#      prob: 4.10737e-11  class: 35 y_test: 13
#      prob: 1.50714e-11  class: 38 y_test: 13
# prob: 0.999999  class: 35 y_test: 35
#      prob: 1.14789e-06  class: 33 y_test: 35
#      prob: 4.19619e-08  class: 3 y_test: 35
#      prob: 4.04128e-08  class: 34 y_test: 35
#      prob: 1.55455e-09  class: 10 y_test: 35
# prob: 0.99962  class: 5 y_test: 5
#      prob: 0.000244789  class: 3 y_test: 5
#      prob: 0.000110878  class: 2 y_test: 5
#      prob: 2.15768e-05  class: 7 y_test: 5
#      prob: 1.66896e-06  class: 1 y_test: 5
# prob: 0.934463  class: 26 y_test: 26
#      prob: 0.0654314  class: 18 y_test: 26
#      prob: 9.62583e-05  class: 22 y_test: 26
#      prob: 3.92733e-06  class: 37 y_test: 26
#      prob: 3.40991e-06  class: 24 y_test: 26
# prob: 1.0  class: 9 y_test: 9
#      prob: 6.66342e-09  class: 10 y_test: 9
#      prob: 3.99329e-09  class: 16 y_test: 9
#      prob: 4.87885e-10  class: 3 y_test: 9
#      prob: 8.65252e-11  class: 12 y_test: 9
# prob: 1.0  class: 16 y_test: 16
#      prob: 1.81615e-08  class: 3 y_test: 16
#      prob: 2.92572e-09  class: 9 y_test: 16
#      prob: 2.00832e-09  class: 41 y_test: 16
#      prob: 1.33681e-09  class: 40 y_test: 16
# prob: 1.0  class: 38 y_test: 38
#      prob: 1.30496e-08  class: 34 y_test: 38
#      prob: 1.02245e-09  class: 13 y_test: 38
#      prob: 1.59437e-10  class: 15 y_test: 38
#      prob: 6.6068e-11  class: 14 y_test: 38
# prob: 0.999951  class: 10 y_test: 10
#      prob: 4.46279e-05  class: 9 y_test: 10
#      prob: 3.85322e-06  class: 7 y_test: 10
#      prob: 3.66447e-07  class: 5 y_test: 10
#      prob: 1.69557e-07  class: 40 y_test: 10
# prob: 0.999978  class: 4 y_test: 4
#      prob: 1.2133e-05  class: 1 y_test: 4
#      prob: 9.90478e-06  class: 0 y_test: 4
#      prob: 3.29806e-08  class: 39 y_test: 4
#      prob: 2.03324e-08  class: 2 y_test: 4
# prob: 0.999998  class: 9 y_test: 9
#      prob: 1.71424e-06  class: 10 y_test: 9
#      prob: 3.15778e-07  class: 16 y_test: 9
#      prob: 1.14101e-08  class: 3 y_test: 9
#      prob: 2.55084e-09  class: 12 y_test: 9
# prob: 0.998536  class: 15 y_test: 15
#      prob: 0.00124274  class: 8 y_test: 15
#      prob: 0.000217972  class: 4 y_test: 15
#      prob: 1.2018e-06  class: 3 y_test: 15
#      prob: 7.43235e-07  class: 7 y_test: 15
# prob: 1.0  class: 9 y_test: 9
#      prob: 5.77617e-09  class: 16 y_test: 9
#      prob: 9.71312e-11  class: 12 y_test: 9
#      prob: 8.73423e-11  class: 10 y_test: 9
#      prob: 5.32387e-13  class: 3 y_test: 9
# prob: 0.712981  class: 26 y_test: 26
#      prob: 0.286404  class: 18 y_test: 26
#      prob: 0.00048188  class: 27 y_test: 26
#      prob: 0.000115481  class: 24 y_test: 26
#      prob: 1.39833e-05  class: 20 y_test: 26
# prob: 0.998321  class: 2 y_test: 2
#      prob: 0.00105415  class: 5 y_test: 2
#      prob: 0.000390762  class: 1 y_test: 2
#      prob: 0.000194146  class: 7 y_test: 2
#      prob: 1.79637e-05  class: 3 y_test: 2
# prob: 0.907404  class: 5 y_test: 5
#      prob: 0.079987  class: 7 y_test: 5
#      prob: 0.00530843  class: 3 y_test: 5
#      prob: 0.00332138  class: 2 y_test: 5
#      prob: 0.00185284  class: 8 y_test: 5
# prob: 0.873558  class: 28 y_test: 28
#      prob: 0.0742349  class: 30 y_test: 28
#      prob: 0.0414378  class: 24 y_test: 28
#      prob: 0.00774593  class: 20 y_test: 28
#      prob: 0.0012949  class: 29 y_test: 28
# prob: 0.99695  class: 11 y_test: 11
#      prob: 0.00303382  class: 30 y_test: 11
#      prob: 7.92852e-06  class: 27 y_test: 11
#      prob: 7.89106e-06  class: 21 y_test: 11
#      prob: 3.19371e-07  class: 40 y_test: 11
# prob: 1.0  class: 25 y_test: 25
#      prob: 3.28643e-07  class: 22 y_test: 25
#      prob: 6.2857e-08  class: 20 y_test: 25
#      prob: 1.9549e-08  class: 29 y_test: 25
#      prob: 6.37466e-11  class: 36 y_test: 25
# prob: 0.337633  class: 30 y_test: 30
#      prob: 0.313115  class: 21 y_test: 30
#      prob: 0.245483  class: 11 y_test: 30
#      prob: 0.0637952  class: 23 y_test: 30
#      prob: 0.0119316  class: 27 y_test: 30
# prob: 0.552728  class: 34 y_test: 34
#      prob: 0.0705345  class: 12 y_test: 34
#      prob: 0.0637866  class: 35 y_test: 34
#      prob: 0.0387186  class: 38 y_test: 34
#      prob: 0.0279748  class: 13 y_test: 34
# prob: 0.999995  class: 5 y_test: 5
#      prob: 2.96428e-06  class: 2 y_test: 5
#      prob: 1.57742e-06  class: 3 y_test: 5
#      prob: 1.0545e-07  class: 7 y_test: 5
#      prob: 1.77569e-09  class: 1 y_test: 5
# prob: 0.999996  class: 12 y_test: 12
#      prob: 3.49683e-06  class: 40 y_test: 12
#      prob: 4.525e-07  class: 7 y_test: 12
#      prob: 5.37519e-09  class: 8 y_test: 12
#      prob: 6.99954e-10  class: 17 y_test: 12
# prob: 0.994559  class: 1 y_test: 1
#      prob: 0.00359319  class: 0 y_test: 1
#      prob: 0.00128405  class: 4 y_test: 1
#      prob: 0.000534016  class: 2 y_test: 1
#      prob: 2.62593e-05  class: 5 y_test: 1
# prob: 0.995459  class: 10 y_test: 10
#      prob: 0.00272161  class: 9 y_test: 10
#      prob: 0.00119373  class: 5 y_test: 10
#      prob: 0.000372966  class: 7 y_test: 10
#      prob: 0.000134222  class: 42 y_test: 10
# prob: 0.998715  class: 25 y_test: 25
#      prob: 0.000977211  class: 20 y_test: 25
#      prob: 8.51873e-05  class: 22 y_test: 25
#      prob: 4.76488e-05  class: 30 y_test: 25
#      prob: 3.78648e-05  class: 29 y_test: 25
# prob: 0.974378  class: 25 y_test: 25
#      prob: 0.00858749  class: 20 y_test: 25
#      prob: 0.00353023  class: 19 y_test: 25
#      prob: 0.0023391  class: 21 y_test: 25
#      prob: 0.00117994  class: 33 y_test: 25
# prob: 0.675272  class: 21 y_test: 21
#      prob: 0.221032  class: 19 y_test: 21
#      prob: 0.0556423  class: 23 y_test: 21
#      prob: 0.0474424  class: 31 y_test: 21
#      prob: 0.000248323  class: 11 y_test: 21
# prob: 0.999867  class: 33 y_test: 33
#      prob: 0.000128597  class: 39 y_test: 33
#      prob: 3.86289e-06  class: 35 y_test: 33
#      prob: 5.01436e-07  class: 14 y_test: 33
#      prob: 3.8477e-07  class: 37 y_test: 33
# prob: 1.0  class: 25 y_test: 25
#      prob: 2.43795e-09  class: 20 y_test: 25
#      prob: 4.64793e-11  class: 22 y_test: 25
#      prob: 4.13512e-11  class: 29 y_test: 25
#      prob: 1.73283e-12  class: 23 y_test: 25
# HIT (0, 83)
# prob: 0.598089  class: 8 y_test: 7
#      prob: 0.348089  class: 7 y_test: 7
#      prob: 0.0168882  class: 16 y_test: 7
#      prob: 0.0151685  class: 40 y_test: 7
#      prob: 0.012232  class: 5 y_test: 7
# prob: 1.0  class: 10 y_test: 10
#      prob: 3.22064e-08  class: 9 y_test: 10
#      prob: 7.98434e-11  class: 42 y_test: 10
#      prob: 1.87633e-11  class: 7 y_test: 10
#      prob: 2.98272e-12  class: 5 y_test: 10
# prob: 0.999954  class: 35 y_test: 35
#      prob: 3.42519e-05  class: 34 y_test: 35
#      prob: 6.92671e-06  class: 33 y_test: 35
#      prob: 3.9813e-06  class: 3 y_test: 35
#      prob: 4.34515e-07  class: 9 y_test: 35
# prob: 0.99997  class: 3 y_test: 3
#      prob: 2.93638e-05  class: 5 y_test: 3
#      prob: 5.60933e-07  class: 2 y_test: 3
#      prob: 1.09105e-10  class: 16 y_test: 3
#      prob: 4.68836e-11  class: 7 y_test: 3
# HIT (0, 87)
# prob: 0.696357  class: 8 y_test: 7
#      prob: 0.256388  class: 7 y_test: 7
#      prob: 0.0175567  class: 5 y_test: 7
#      prob: 0.00863973  class: 1 y_test: 7
#      prob: 0.00689421  class: 4 y_test: 7
# prob: 0.999998  class: 22 y_test: 22
#      prob: 9.20484e-07  class: 26 y_test: 22
#      prob: 7.44292e-07  class: 29 y_test: 22
#      prob: 4.66485e-08  class: 25 y_test: 22
#      prob: 1.62206e-08  class: 18 y_test: 22
# prob: 1.0  class: 13 y_test: 13
#      prob: 4.78029e-11  class: 15 y_test: 13
#      prob: 9.92617e-12  class: 35 y_test: 13
#      prob: 3.53753e-12  class: 12 y_test: 13
#      prob: 2.16414e-12  class: 38 y_test: 13
# prob: 0.989023  class: 3 y_test: 3
#      prob: 0.0109493  class: 5 y_test: 3
#      prob: 2.56045e-05  class: 2 y_test: 3
#      prob: 8.41884e-07  class: 7 y_test: 3
#      prob: 5.11053e-07  class: 10 y_test: 3
# prob: 0.99999  class: 1 y_test: 1
#      prob: 1.03636e-05  class: 0 y_test: 1
#      prob: 5.35023e-08  class: 2 y_test: 1
#      prob: 3.83616e-08  class: 4 y_test: 1
#      prob: 4.36608e-09  class: 5 y_test: 1
# prob: 1.0  class: 2 y_test: 2
#      prob: 2.60229e-10  class: 1 y_test: 2
#      prob: 2.5541e-10  class: 5 y_test: 2
#      prob: 3.92488e-13  class: 7 y_test: 2
#      prob: 3.11877e-15  class: 3 y_test: 2
# prob: 0.999975  class: 14 y_test: 14
#      prob: 1.85167e-05  class: 15 y_test: 14
#      prob: 4.98281e-06  class: 38 y_test: 14
#      prob: 8.85411e-07  class: 4 y_test: 14
#      prob: 2.84769e-07  class: 39 y_test: 14
# prob: 1.0  class: 12 y_test: 12
#      prob: 6.56878e-15  class: 40 y_test: 12
#      prob: 6.59144e-16  class: 7 y_test: 12
#      prob: 4.18344e-21  class: 8 y_test: 12
#      prob: 3.19984e-22  class: 9 y_test: 12
# prob: 0.545622  class: 32 y_test: 32
#      prob: 0.396723  class: 6 y_test: 32
#      prob: 0.0359438  class: 1 y_test: 32
#      prob: 0.00895335  class: 41 y_test: 32
#      prob: 0.00575528  class: 42 y_test: 32
# prob: 0.998356  class: 3 y_test: 3
#      prob: 0.00162706  class: 5 y_test: 3
#      prob: 1.71253e-05  class: 2 y_test: 3
#      prob: 7.11623e-08  class: 7 y_test: 3
#      prob: 3.69398e-08  class: 16 y_test: 3
# prob: 1.0  class: 38 y_test: 38
#      prob: 3.09797e-13  class: 34 y_test: 38
#      prob: 2.53612e-16  class: 14 y_test: 38
#      prob: 9.93751e-18  class: 36 y_test: 38
#      prob: 3.40855e-18  class: 13 y_test: 38
# prob: 1.0  class: 9 y_test: 9
#      prob: 5.1334e-10  class: 16 y_test: 9
#      prob: 4.2382e-11  class: 10 y_test: 9
#      prob: 1.92946e-11  class: 12 y_test: 9
#      prob: 4.70302e-13  class: 3 y_test: 9
# prob: 0.99991  class: 33 y_test: 33
#      prob: 8.73004e-05  class: 39 y_test: 33
#      prob: 1.87101e-06  class: 35 y_test: 33
#      prob: 5.13228e-07  class: 37 y_test: 33
#      prob: 2.43852e-07  class: 14 y_test: 33
# prob: 0.997808  class: 1 y_test: 1
#      prob: 0.00217437  class: 0 y_test: 1
#      prob: 1.61251e-05  class: 2 y_test: 1
#      prob: 1.94702e-06  class: 4 y_test: 1
#      prob: 1.06201e-08  class: 8 y_test: 1
# prob: 1.0  class: 10 y_test: 10
#      prob: 1.42048e-07  class: 9 y_test: 10
#      prob: 5.7586e-08  class: 5 y_test: 10
#      prob: 9.77994e-09  class: 42 y_test: 10
#      prob: 6.32356e-09  class: 7 y_test: 10
# HIT (0, 102)
# prob: 0.321406  class: 4 y_test: 5
#      prob: 0.250555  class: 15 y_test: 5
#      prob: 0.206863  class: 5 y_test: 5
#      prob: 0.136198  class: 8 y_test: 5
#      prob: 0.0519084  class: 2 y_test: 5
# prob: 0.936152  class: 11 y_test: 11
#      prob: 0.0527736  class: 30 y_test: 11
#      prob: 0.0047693  class: 21 y_test: 11
#      prob: 0.00441965  class: 27 y_test: 11
#      prob: 0.00148569  class: 23 y_test: 11
# prob: 0.999999  class: 33 y_test: 33
#      prob: 1.39717e-06  class: 39 y_test: 33
#      prob: 5.45237e-10  class: 35 y_test: 33
#      prob: 3.8798e-10  class: 37 y_test: 33
#      prob: 4.34842e-12  class: 14 y_test: 33
# prob: 0.999999  class: 4 y_test: 4
#      prob: 6.55133e-07  class: 1 y_test: 4
#      prob: 5.77432e-08  class: 8 y_test: 4
#      prob: 3.67382e-08  class: 0 y_test: 4
#      prob: 1.3298e-08  class: 2 y_test: 4
# prob: 1.0  class: 35 y_test: 35
#      prob: 5.28473e-10  class: 3 y_test: 35
#      prob: 2.95551e-10  class: 34 y_test: 35
#      prob: 1.47087e-10  class: 33 y_test: 35
#      prob: 1.31561e-12  class: 9 y_test: 35
# prob: 0.995486  class: 25 y_test: 25
#      prob: 0.00295453  class: 22 y_test: 25
#      prob: 0.00116025  class: 29 y_test: 25
#      prob: 0.000327381  class: 20 y_test: 25
#      prob: 2.92782e-05  class: 24 y_test: 25
# prob: 0.999282  class: 33 y_test: 33
#      prob: 0.000372079  class: 14 y_test: 33
#      prob: 0.000225129  class: 39 y_test: 33
#      prob: 8.5287e-05  class: 35 y_test: 33
#      prob: 2.93229e-05  class: 17 y_test: 33
# prob: 0.989492  class: 4 y_test: 4
#      prob: 0.00926049  class: 1 y_test: 4
#      prob: 0.000496778  class: 2 y_test: 4
#      prob: 0.000365247  class: 8 y_test: 4
#      prob: 0.000290094  class: 0 y_test: 4
# prob: 0.99992  class: 1 y_test: 1
#      prob: 6.93713e-05  class: 0 y_test: 1
#      prob: 8.46502e-06  class: 2 y_test: 1
#      prob: 1.03899e-06  class: 4 y_test: 1
#      prob: 7.6335e-07  class: 5 y_test: 1
# prob: 1.0  class: 14 y_test: 14
#      prob: 3.7758e-08  class: 17 y_test: 14
#      prob: 2.81302e-08  class: 38 y_test: 14
#      prob: 1.02839e-08  class: 15 y_test: 14
#      prob: 3.5941e-09  class: 33 y_test: 14
# prob: 0.999998  class: 16 y_test: 16
#      prob: 1.86465e-06  class: 9 y_test: 16
#      prob: 3.67821e-08  class: 3 y_test: 16
#      prob: 2.54421e-10  class: 28 y_test: 16
#      prob: 3.22071e-11  class: 41 y_test: 16
# prob: 0.999363  class: 10 y_test: 10
#      prob: 0.000607101  class: 9 y_test: 10
#      prob: 1.60387e-05  class: 5 y_test: 10
#      prob: 5.47988e-06  class: 23 y_test: 10
#      prob: 3.9974e-06  class: 42 y_test: 10
# HIT (0, 114)
# prob: 0.822133  class: 23 y_test: 30
#      prob: 0.0335464  class: 5 y_test: 30
#      prob: 0.0262989  class: 21 y_test: 30
#      prob: 0.0195954  class: 19 y_test: 30
#      prob: 0.0182163  class: 12 y_test: 30
# prob: 0.997919  class: 3 y_test: 3
#      prob: 0.00207184  class: 5 y_test: 3
#      prob: 8.9063e-06  class: 2 y_test: 3
#      prob: 1.88236e-08  class: 7 y_test: 3
#      prob: 2.32336e-09  class: 10 y_test: 3
# prob: 0.876767  class: 27 y_test: 27
#      prob: 0.0362343  class: 11 y_test: 27
#      prob: 0.0319816  class: 24 y_test: 27
#      prob: 0.0249108  class: 18 y_test: 27
#      prob: 0.00680698  class: 23 y_test: 27
# HIT (0, 117)
# prob: 0.780034  class: 31 y_test: 29
#      prob: 0.087226  class: 24 y_test: 29
#      prob: 0.0735991  class: 29 y_test: 29
#      prob: 0.0164938  class: 21 y_test: 29
#      prob: 0.0124342  class: 30 y_test: 29
# prob: 0.696621  class: 1 y_test: 1
#      prob: 0.301852  class: 4 y_test: 1
#      prob: 0.00099109  class: 2 y_test: 1
#      prob: 0.000481465  class: 0 y_test: 1
#      prob: 2.80944e-05  class: 7 y_test: 1
# prob: 0.922871  class: 17 y_test: 17
#      prob: 0.0365092  class: 14 y_test: 17
#      prob: 0.0145706  class: 38 y_test: 17
#      prob: 0.0116393  class: 8 y_test: 17
#      prob: 0.00675493  class: 4 y_test: 17
# prob: 1.0  class: 13 y_test: 13
#      prob: 7.42961e-09  class: 15 y_test: 13
#      prob: 9.60802e-10  class: 38 y_test: 13
#      prob: 4.97035e-10  class: 12 y_test: 13
#      prob: 2.14101e-10  class: 35 y_test: 13
# prob: 0.999896  class: 7 y_test: 7
#      prob: 0.000100019  class: 8 y_test: 7
#      prob: 3.66656e-06  class: 5 y_test: 7
#      prob: 2.34866e-07  class: 40 y_test: 7
#      prob: 1.34782e-07  class: 12 y_test: 7
# prob: 0.975889  class: 1 y_test: 1
#      prob: 0.00834296  class: 4 y_test: 1
#      prob: 0.0078299  class: 2 y_test: 1
#      prob: 0.00780843  class: 0 y_test: 1
#      prob: 5.44997e-05  class: 7 y_test: 1
# prob: 0.993818  class: 8 y_test: 8
#      prob: 0.00461887  class: 15 y_test: 8
#      prob: 0.000891596  class: 4 y_test: 8
#      prob: 0.000279558  class: 0 y_test: 8
#      prob: 0.000183302  class: 7 y_test: 8
# prob: 1.0  class: 2 y_test: 2
#      prob: 9.15794e-09  class: 1 y_test: 2
#      prob: 7.55744e-09  class: 5 y_test: 2
#      prob: 2.58899e-10  class: 3 y_test: 2
#      prob: 6.88738e-12  class: 7 y_test: 2
# prob: 0.998205  class: 10 y_test: 10
#      prob: 0.00173509  class: 9 y_test: 10
#      prob: 4.29727e-05  class: 7 y_test: 10
#      prob: 8.0975e-06  class: 5 y_test: 10
#      prob: 5.97267e-06  class: 40 y_test: 10
# prob: 0.999216  class: 10 y_test: 10
#      prob: 0.000706861  class: 9 y_test: 10
#      prob: 4.75684e-05  class: 5 y_test: 10
#      prob: 1.513e-05  class: 7 y_test: 10
#      prob: 6.19367e-06  class: 42 y_test: 10
# HIT (0, 127)
# prob: 0.610302  class: 18 y_test: 30
#      prob: 0.320379  class: 26 y_test: 30
#      prob: 0.0299832  class: 24 y_test: 30
#      prob: 0.0188548  class: 22 y_test: 30
#      prob: 0.00669195  class: 29 y_test: 30
# prob: 1.0  class: 1 y_test: 1
#      prob: 9.26737e-08  class: 0 y_test: 1
#      prob: 9.06239e-10  class: 2 y_test: 1
#      prob: 2.99526e-11  class: 5 y_test: 1
#      prob: 1.27024e-11  class: 6 y_test: 1
# prob: 0.775223  class: 6 y_test: 6
#      prob: 0.18906  class: 42 y_test: 6
#      prob: 0.031176  class: 32 y_test: 6
#      prob: 0.00294278  class: 41 y_test: 6
#      prob: 0.00147313  class: 1 y_test: 6
# prob: 0.999995  class: 36 y_test: 36
#      prob: 2.55916e-06  class: 38 y_test: 36
#      prob: 2.04637e-06  class: 32 y_test: 36
#      prob: 3.30872e-07  class: 25 y_test: 36
#      prob: 2.3793e-08  class: 12 y_test: 36
# HIT (0, 131)
# prob: 0.535678  class: 5 y_test: 3
#      prob: 0.146192  class: 7 y_test: 3
#      prob: 0.096864  class: 3 y_test: 3
#      prob: 0.0385791  class: 42 y_test: 3
#      prob: 0.0370539  class: 6 y_test: 3
# prob: 0.999994  class: 14 y_test: 14
#      prob: 3.98785e-06  class: 38 y_test: 14
#      prob: 4.79113e-07  class: 17 y_test: 14
#      prob: 4.26758e-07  class: 39 y_test: 14
#      prob: 3.95868e-07  class: 33 y_test: 14
# prob: 1.0  class: 13 y_test: 13
#      prob: 3.13106e-16  class: 38 y_test: 13
#      prob: 1.05022e-16  class: 12 y_test: 13
#      prob: 9.63155e-17  class: 15 y_test: 13
#      prob: 1.92321e-18  class: 35 y_test: 13
# prob: 0.781066  class: 11 y_test: 11
#      prob: 0.217306  class: 30 y_test: 11
#      prob: 0.000880065  class: 28 y_test: 11
#      prob: 0.000498927  class: 21 y_test: 11
#      prob: 0.000116973  class: 23 y_test: 11
# prob: 1.0  class: 10 y_test: 10
#      prob: 4.75395e-07  class: 9 y_test: 10
#      prob: 2.97374e-10  class: 5 y_test: 10
#      prob: 3.65645e-11  class: 7 y_test: 10
#      prob: 2.67991e-11  class: 42 y_test: 10
# prob: 0.999919  class: 18 y_test: 18
#      prob: 6.52428e-05  class: 27 y_test: 18
#      prob: 1.54936e-05  class: 26 y_test: 18
#      prob: 2.2055e-07  class: 24 y_test: 18
#      prob: 1.79575e-10  class: 37 y_test: 18
# prob: 0.711785  class: 40 y_test: 40
#      prob: 0.195771  class: 7 y_test: 40
#      prob: 0.0369219  class: 12 y_test: 40
#      prob: 0.0132808  class: 42 y_test: 40
#      prob: 0.0114925  class: 1 y_test: 40
# prob: 1.0  class: 2 y_test: 2
#      prob: 2.12132e-07  class: 5 y_test: 2
#      prob: 2.10394e-10  class: 3 y_test: 2
#      prob: 2.06577e-10  class: 1 y_test: 2
#      prob: 1.91226e-10  class: 7 y_test: 2
# prob: 0.999674  class: 38 y_test: 38
#      prob: 0.000301063  class: 34 y_test: 38
#      prob: 1.25071e-05  class: 36 y_test: 38
#      prob: 4.3201e-06  class: 13 y_test: 38
#      prob: 3.06279e-06  class: 15 y_test: 38
# prob: 0.999992  class: 41 y_test: 41
#      prob: 6.92012e-06  class: 42 y_test: 41
#      prob: 7.01319e-07  class: 32 y_test: 41
#      prob: 8.35849e-08  class: 12 y_test: 41
#      prob: 3.23243e-09  class: 40 y_test: 41
# prob: 0.999997  class: 4 y_test: 4
#      prob: 2.24696e-06  class: 8 y_test: 4
#      prob: 9.10996e-07  class: 1 y_test: 4
#      prob: 1.73308e-07  class: 0 y_test: 4
#      prob: 3.51284e-08  class: 2 y_test: 4
# prob: 0.999928  class: 6 y_test: 6
#      prob: 5.88615e-05  class: 32 y_test: 6
#      prob: 1.2627e-05  class: 42 y_test: 6
#      prob: 8.7122e-07  class: 1 y_test: 6
#      prob: 3.37975e-10  class: 41 y_test: 6
# prob: 0.998756  class: 18 y_test: 18
#      prob: 0.00119253  class: 27 y_test: 18
#      prob: 3.17625e-05  class: 26 y_test: 18
#      prob: 1.93016e-05  class: 24 y_test: 18
#      prob: 2.53224e-09  class: 28 y_test: 18
# prob: 0.999998  class: 17 y_test: 17
#      prob: 1.70015e-06  class: 14 y_test: 17
#      prob: 2.19223e-09  class: 33 y_test: 17
#      prob: 3.39312e-10  class: 40 y_test: 17
#      prob: 1.22015e-10  class: 37 y_test: 17
# HIT (0, 145)
# prob: 0.580165  class: 18 y_test: 25
#      prob: 0.104675  class: 26 y_test: 25
#      prob: 0.0766209  class: 31 y_test: 25
#      prob: 0.0570724  class: 4 y_test: 25
#      prob: 0.0397954  class: 19 y_test: 25
# prob: 1.0  class: 2 y_test: 2
#      prob: 6.07e-10  class: 1 y_test: 2
#      prob: 1.13857e-11  class: 5 y_test: 2
#      prob: 9.95061e-15  class: 3 y_test: 2
#      prob: 4.3639e-15  class: 7 y_test: 2
# prob: 0.974773  class: 41 y_test: 41
#      prob: 0.0205707  class: 12 y_test: 41
#      prob: 0.00182587  class: 32 y_test: 41
#      prob: 0.00143374  class: 16 y_test: 41
#      prob: 0.000804215  class: 42 y_test: 41
# prob: 0.999236  class: 11 y_test: 11
#      prob: 0.000715355  class: 30 y_test: 11
#      prob: 2.89966e-05  class: 40 y_test: 11
#      prob: 1.19259e-05  class: 21 y_test: 11
#      prob: 3.93351e-06  class: 33 y_test: 11
# prob: 0.89853  class: 21 y_test: 21
#      prob: 0.0506956  class: 19 y_test: 21
#      prob: 0.0327089  class: 31 y_test: 21
#      prob: 0.017157  class: 23 y_test: 21
#      prob: 0.000388338  class: 11 y_test: 21
# prob: 0.999084  class: 7 y_test: 7
#      prob: 0.000461032  class: 8 y_test: 7
#      prob: 0.000376  class: 5 y_test: 7
#      prob: 6.55251e-05  class: 40 y_test: 7
#      prob: 8.53928e-06  class: 2 y_test: 7
# prob: 0.54266  class: 24 y_test: 24
#      prob: 0.372436  class: 18 y_test: 24
#      prob: 0.0758904  class: 27 y_test: 24
#      prob: 0.00791822  class: 28 y_test: 24
#      prob: 0.000295387  class: 30 y_test: 24
# prob: 0.999847  class: 11 y_test: 11
#      prob: 0.000104291  class: 30 y_test: 11
#      prob: 4.58153e-05  class: 21 y_test: 11
#      prob: 2.48071e-06  class: 27 y_test: 11
#      prob: 1.97768e-07  class: 23 y_test: 11
# prob: 1.0  class: 25 y_test: 25
#      prob: 4.74218e-07  class: 20 y_test: 25
#      prob: 1.38603e-09  class: 22 y_test: 25
#      prob: 4.78773e-10  class: 29 y_test: 25
#      prob: 1.69667e-10  class: 24 y_test: 25
# prob: 0.99996  class: 17 y_test: 17
#      prob: 4.03929e-05  class: 14 y_test: 17
#      prob: 1.93334e-09  class: 33 y_test: 17
#      prob: 9.47577e-10  class: 22 y_test: 17
#      prob: 2.65336e-10  class: 40 y_test: 17
# prob: 0.999355  class: 3 y_test: 3
#      prob: 0.00064428  class: 5 y_test: 3
#      prob: 6.39417e-07  class: 16 y_test: 3
#      prob: 4.07003e-07  class: 2 y_test: 3
#      prob: 1.61719e-07  class: 35 y_test: 3
# prob: 0.989633  class: 6 y_test: 6
#      prob: 0.00966231  class: 42 y_test: 6
#      prob: 0.000652119  class: 32 y_test: 6
#      prob: 4.66418e-05  class: 1 y_test: 6
#      prob: 5.46384e-06  class: 41 y_test: 6
# prob: 0.999985  class: 9 y_test: 9
#      prob: 1.19661e-05  class: 16 y_test: 9
#      prob: 2.44608e-06  class: 10 y_test: 9
#      prob: 1.14512e-07  class: 19 y_test: 9
#      prob: 1.8602e-08  class: 3 y_test: 9
# prob: 0.999737  class: 7 y_test: 7
#      prob: 0.000256621  class: 8 y_test: 7
#      prob: 6.0804e-06  class: 5 y_test: 7
#      prob: 3.5758e-08  class: 12 y_test: 7
#      prob: 3.28494e-08  class: 2 y_test: 7
# prob: 0.999987  class: 4 y_test: 4
#      prob: 1.04609e-05  class: 1 y_test: 4
#      prob: 1.19795e-06  class: 0 y_test: 4
#      prob: 7.84356e-07  class: 8 y_test: 4
#      prob: 4.6685e-08  class: 2 y_test: 4
# prob: 1.0  class: 13 y_test: 13
#      prob: 1.88028e-12  class: 12 y_test: 13
#      prob: 1.14829e-12  class: 38 y_test: 13
#      prob: 4.1016e-13  class: 35 y_test: 13
#      prob: 1.25072e-13  class: 15 y_test: 13
# prob: 0.999994  class: 16 y_test: 16
#      prob: 5.18329e-06  class: 9 y_test: 16
#      prob: 7.34537e-07  class: 3 y_test: 16
#      prob: 8.09211e-10  class: 40 y_test: 16
#      prob: 6.48886e-10  class: 7 y_test: 16
# prob: 0.999999  class: 4 y_test: 4
#      prob: 1.0014e-06  class: 1 y_test: 4
#      prob: 1.92427e-08  class: 8 y_test: 4
#      prob: 1.59737e-08  class: 0 y_test: 4
#      prob: 1.08668e-08  class: 2 y_test: 4
# prob: 0.320304  class: 25 y_test: 25
#      prob: 0.245616  class: 24 y_test: 25
#      prob: 0.14971  class: 27 y_test: 25
#      prob: 0.14721  class: 20 y_test: 25
#      prob: 0.0673576  class: 18 y_test: 25
# prob: 0.999355  class: 18 y_test: 18
#      prob: 0.000325186  class: 26 y_test: 18
#      prob: 0.000317228  class: 27 y_test: 18
#      prob: 2.75542e-06  class: 24 y_test: 18
#      prob: 9.85124e-10  class: 28 y_test: 18
# prob: 0.999998  class: 9 y_test: 9
#      prob: 5.65555e-07  class: 16 y_test: 9
#      prob: 5.64805e-07  class: 12 y_test: 9
#      prob: 3.96587e-07  class: 10 y_test: 9
#      prob: 7.73523e-09  class: 23 y_test: 9
# prob: 1.0  class: 13 y_test: 13
#      prob: 1.31657e-07  class: 12 y_test: 13
#      prob: 4.70521e-09  class: 35 y_test: 13
#      prob: 2.92031e-09  class: 9 y_test: 13
#      prob: 1.34356e-09  class: 15 y_test: 13
# prob: 1.0  class: 14 y_test: 14
#      prob: 1.00057e-07  class: 38 y_test: 14
#      prob: 5.46157e-08  class: 39 y_test: 14
#      prob: 2.16639e-08  class: 15 y_test: 14
#      prob: 1.7487e-08  class: 17 y_test: 14
# prob: 0.999832  class: 29 y_test: 29
#      prob: 0.000102829  class: 22 y_test: 29
#      prob: 4.20476e-05  class: 28 y_test: 29
#      prob: 1.64624e-05  class: 25 y_test: 29
#      prob: 2.39378e-06  class: 30 y_test: 29
# prob: 0.995965  class: 17 y_test: 17
#      prob: 0.00362439  class: 14 y_test: 17
#      prob: 0.000113518  class: 22 y_test: 17
#      prob: 8.45766e-05  class: 34 y_test: 17
#      prob: 4.03837e-05  class: 40 y_test: 17
# prob: 1.0  class: 13 y_test: 13
#      prob: 6.32255e-16  class: 12 y_test: 13
#      prob: 1.89604e-17  class: 38 y_test: 13
#      prob: 6.92634e-19  class: 15 y_test: 13
#      prob: 1.99489e-19  class: 35 y_test: 13
# prob: 0.994536  class: 38 y_test: 38
#      prob: 0.00517035  class: 34 y_test: 38
#      prob: 8.25111e-05  class: 36 y_test: 38
#      prob: 7.4625e-05  class: 14 y_test: 38
#      prob: 5.31351e-05  class: 40 y_test: 38
# prob: 0.865384  class: 26 y_test: 26
#      prob: 0.134592  class: 18 y_test: 26
#      prob: 2.19632e-05  class: 22 y_test: 26
#      prob: 1.75791e-06  class: 24 y_test: 26
#      prob: 2.8745e-07  class: 27 y_test: 26
# prob: 0.999854  class: 25 y_test: 25
#      prob: 0.000134611  class: 20 y_test: 25
#      prob: 7.05651e-06  class: 22 y_test: 25
#      prob: 2.77155e-06  class: 29 y_test: 25
#      prob: 1.07686e-06  class: 24 y_test: 25
# prob: 0.999421  class: 33 y_test: 33
#      prob: 0.000141739  class: 39 y_test: 33
#      prob: 0.000136672  class: 35 y_test: 33
#      prob: 0.000119727  class: 9 y_test: 33
#      prob: 5.04106e-05  class: 40 y_test: 33
# prob: 0.895774  class: 1 y_test: 1
#      prob: 0.0983248  class: 2 y_test: 1
#      prob: 0.001889  class: 5 y_test: 1
#      prob: 0.001647  class: 0 y_test: 1
#      prob: 0.00135646  class: 6 y_test: 1
# HIT (0, 176)
# prob: 0.957668  class: 5 y_test: 3
#      prob: 0.0331238  class: 3 y_test: 3
#      prob: 0.00799101  class: 7 y_test: 3
#      prob: 0.000647712  class: 2 y_test: 3
#      prob: 0.00025774  class: 1 y_test: 3
# HIT (0, 177)
# prob: 0.536588  class: 7 y_test: 40
#      prob: 0.397574  class: 40 y_test: 40
#      prob: 0.0444703  class: 10 y_test: 40
#      prob: 0.00748458  class: 42 y_test: 40
#      prob: 0.00729584  class: 5 y_test: 40
# prob: 1.0  class: 13 y_test: 13
#      prob: 2.16611e-09  class: 15 y_test: 13
#      prob: 3.88259e-10  class: 35 y_test: 13
#      prob: 1.5013e-10  class: 12 y_test: 13
#      prob: 9.03405e-11  class: 38 y_test: 13
# prob: 0.999983  class: 2 y_test: 2
#      prob: 8.66456e-06  class: 1 y_test: 2
#      prob: 7.8476e-06  class: 5 y_test: 2
#      prob: 3.58952e-07  class: 7 y_test: 2
#      prob: 6.2863e-08  class: 3 y_test: 2
# prob: 0.996402  class: 8 y_test: 8
#      prob: 0.00358561  class: 7 y_test: 8
#      prob: 4.13064e-06  class: 15 y_test: 8
#      prob: 2.94812e-06  class: 4 y_test: 8
#      prob: 2.80844e-06  class: 5 y_test: 8
# prob: 0.999946  class: 4 y_test: 4
#      prob: 4.5117e-05  class: 1 y_test: 4
#      prob: 3.72884e-06  class: 2 y_test: 4
#      prob: 3.41295e-06  class: 8 y_test: 4
#      prob: 7.16257e-07  class: 0 y_test: 4
# prob: 1.0  class: 36 y_test: 36
#      prob: 2.25193e-08  class: 38 y_test: 36
#      prob: 2.87997e-09  class: 32 y_test: 36
#      prob: 1.68553e-10  class: 25 y_test: 36
#      prob: 1.2337e-10  class: 20 y_test: 36
# prob: 0.999988  class: 25 y_test: 25
#      prob: 6.43146e-06  class: 20 y_test: 25
#      prob: 1.81406e-06  class: 29 y_test: 25
#      prob: 1.74815e-06  class: 30 y_test: 25
#      prob: 8.78965e-07  class: 22 y_test: 25
# prob: 0.835983  class: 20 y_test: 20
#      prob: 0.0904639  class: 28 y_test: 20
#      prob: 0.0403672  class: 30 y_test: 20
#      prob: 0.017532  class: 23 y_test: 20
#      prob: 0.00881731  class: 24 y_test: 20
# prob: 0.999997  class: 25 y_test: 25
#      prob: 2.06128e-06  class: 20 y_test: 25
#      prob: 5.73622e-07  class: 29 y_test: 25
#      prob: 2.68337e-07  class: 30 y_test: 25
#      prob: 1.83172e-07  class: 23 y_test: 25
# prob: 0.876052  class: 18 y_test: 18
#      prob: 0.0515537  class: 27 y_test: 18
#      prob: 0.0507762  class: 26 y_test: 18
#      prob: 0.0128092  class: 24 y_test: 18
#      prob: 0.00308309  class: 20 y_test: 18
# prob: 0.985564  class: 1 y_test: 1
#      prob: 0.0133555  class: 2 y_test: 1
#      prob: 0.000703094  class: 4 y_test: 1
#      prob: 0.000238813  class: 0 y_test: 1
#      prob: 0.000133764  class: 5 y_test: 1
# prob: 0.999981  class: 10 y_test: 10
#      prob: 1.77011e-05  class: 9 y_test: 10
#      prob: 6.15601e-07  class: 5 y_test: 10
#      prob: 6.08512e-07  class: 7 y_test: 10
#      prob: 3.5151e-07  class: 42 y_test: 10
# prob: 0.996118  class: 8 y_test: 8
#      prob: 0.00387488  class: 7 y_test: 8
#      prob: 6.53301e-06  class: 4 y_test: 8
#      prob: 5.55281e-07  class: 15 y_test: 8
#      prob: 1.24557e-07  class: 2 y_test: 8
# prob: 0.896974  class: 10 y_test: 10
#      prob: 0.0495636  class: 5 y_test: 10
#      prob: 0.0170696  class: 9 y_test: 10
#      prob: 0.0145418  class: 7 y_test: 10
#      prob: 0.00690283  class: 42 y_test: 10
# prob: 0.998504  class: 29 y_test: 29
#      prob: 0.000898738  class: 28 y_test: 29
#      prob: 0.000566333  class: 22 y_test: 29
#      prob: 1.07909e-05  class: 30 y_test: 29
#      prob: 1.01695e-05  class: 25 y_test: 29
# prob: 1.0  class: 12 y_test: 12
#      prob: 3.33558e-10  class: 40 y_test: 12
#      prob: 1.54967e-11  class: 7 y_test: 12
#      prob: 7.89727e-15  class: 8 y_test: 12
#      prob: 6.6917e-15  class: 9 y_test: 12
# prob: 0.9988  class: 38 y_test: 38
#      prob: 0.0011217  class: 13 y_test: 38
#      prob: 4.57765e-05  class: 14 y_test: 38
#      prob: 2.52797e-05  class: 34 y_test: 38
#      prob: 6.13389e-06  class: 12 y_test: 38
# prob: 0.949767  class: 31 y_test: 31
#      prob: 0.0490643  class: 21 y_test: 31
#      prob: 0.000837202  class: 19 y_test: 31
#      prob: 0.000255582  class: 23 y_test: 31
#      prob: 7.14575e-05  class: 29 y_test: 31
# prob: 1.0  class: 2 y_test: 2
#      prob: 6.69059e-10  class: 5 y_test: 2
#      prob: 1.30168e-11  class: 1 y_test: 2
#      prob: 7.08299e-12  class: 7 y_test: 2
#      prob: 5.50628e-12  class: 3 y_test: 2
# prob: 0.927869  class: 8 y_test: 8
#      prob: 0.0667847  class: 7 y_test: 8
#      prob: 0.0046885  class: 4 y_test: 8
#      prob: 0.000390476  class: 15 y_test: 8
#      prob: 0.000150272  class: 2 y_test: 8
# prob: 0.962361  class: 38 y_test: 38
#      prob: 0.0195833  class: 36 y_test: 38
#      prob: 0.00996782  class: 34 y_test: 38
#      prob: 0.0036574  class: 32 y_test: 38
#      prob: 0.00142715  class: 14 y_test: 38
# HIT (0, 198)
# prob: 0.438493  class: 33 y_test: 18
#      prob: 0.370625  class: 19 y_test: 18
#      prob: 0.109269  class: 39 y_test: 18
#      prob: 0.061497  class: 37 y_test: 18
#      prob: 0.0141885  class: 40 y_test: 18
# prob: 0.975251  class: 28 y_test: 28
#      prob: 0.0234767  class: 20 y_test: 28
#      prob: 0.00099898  class: 29 y_test: 28
#      prob: 0.00018563  class: 30 y_test: 28
#      prob: 4.21594e-05  class: 24 y_test: 28
# prob: 0.999977  class: 17 y_test: 17
#      prob: 2.31273e-05  class: 14 y_test: 17
#      prob: 9.23997e-09  class: 34 y_test: 17
#      prob: 1.07659e-09  class: 40 y_test: 17
#      prob: 1.0244e-09  class: 12 y_test: 17
# prob: 0.959073  class: 9 y_test: 9
#      prob: 0.0408663  class: 10 y_test: 9
#      prob: 3.40977e-05  class: 16 y_test: 9
#      prob: 1.3138e-05  class: 23 y_test: 9
#      prob: 5.45031e-06  class: 7 y_test: 9
# prob: 0.999525  class: 4 y_test: 4
#      prob: 0.000400698  class: 1 y_test: 4
#      prob: 2.68423e-05  class: 2 y_test: 4
#      prob: 2.49409e-05  class: 0 y_test: 4
#      prob: 2.03338e-05  class: 8 y_test: 4
# prob: 0.992329  class: 1 y_test: 1
#      prob: 0.00542807  class: 4 y_test: 1
#      prob: 0.00221166  class: 0 y_test: 1
#      prob: 3.13167e-05  class: 2 y_test: 1
#      prob: 1.40169e-07  class: 5 y_test: 1
# prob: 1.0  class: 17 y_test: 17
#      prob: 9.74524e-08  class: 14 y_test: 17
#      prob: 1.28515e-09  class: 40 y_test: 17
#      prob: 4.53488e-11  class: 33 y_test: 17
#      prob: 1.21179e-11  class: 37 y_test: 17
# prob: 1.0  class: 9 y_test: 9
#      prob: 1.84126e-07  class: 10 y_test: 9
#      prob: 5.4984e-09  class: 16 y_test: 9
#      prob: 5.41597e-10  class: 12 y_test: 9
#      prob: 2.4428e-10  class: 3 y_test: 9
# prob: 0.978183  class: 2 y_test: 2
#      prob: 0.0172511  class: 5 y_test: 2
#      prob: 0.00229689  class: 3 y_test: 2
#      prob: 0.00196215  class: 7 y_test: 2
#      prob: 0.000239403  class: 1 y_test: 2
# prob: 0.653212  class: 31 y_test: 31
#      prob: 0.189036  class: 21 y_test: 31
#      prob: 0.0712235  class: 19 y_test: 31
#      prob: 0.0461222  class: 23 y_test: 31
#      prob: 0.0116091  class: 29 y_test: 31
# prob: 1.0  class: 13 y_test: 13
#      prob: 1.81789e-08  class: 15 y_test: 13
#      prob: 4.09808e-09  class: 38 y_test: 13
#      prob: 3.40743e-10  class: 12 y_test: 13
#      prob: 8.092e-11  class: 5 y_test: 13
# prob: 0.995327  class: 15 y_test: 15
#      prob: 0.00172712  class: 13 y_test: 15
#      prob: 0.00116292  class: 35 y_test: 15
#      prob: 0.00104587  class: 34 y_test: 15
#      prob: 0.000268061  class: 8 y_test: 15
# prob: 0.999937  class: 15 y_test: 15
#      prob: 3.65992e-05  class: 13 y_test: 15
#      prob: 2.05151e-05  class: 8 y_test: 15
#      prob: 2.37043e-06  class: 4 y_test: 15
#      prob: 1.12677e-06  class: 3 y_test: 15
# prob: 1.0  class: 38 y_test: 38
#      prob: 2.48482e-12  class: 34 y_test: 38
#      prob: 5.07713e-14  class: 13 y_test: 38
#      prob: 3.64909e-14  class: 14 y_test: 38
#      prob: 9.15176e-17  class: 15 y_test: 38
# prob: 1.0  class: 25 y_test: 25
#      prob: 1.35367e-10  class: 20 y_test: 25
#      prob: 1.80782e-13  class: 22 y_test: 25
#      prob: 1.49023e-13  class: 29 y_test: 25
#      prob: 2.66274e-14  class: 24 y_test: 25
# prob: 0.983629  class: 5 y_test: 5
#      prob: 0.00744196  class: 2 y_test: 5
#      prob: 0.00590577  class: 3 y_test: 5
#      prob: 0.00290008  class: 7 y_test: 5
#      prob: 6.581e-05  class: 1 y_test: 5
# prob: 1.0  class: 25 y_test: 25
#      prob: 6.26304e-10  class: 20 y_test: 25
#      prob: 6.14466e-12  class: 29 y_test: 25
#      prob: 3.68726e-12  class: 22 y_test: 25
#      prob: 1.22676e-13  class: 23 y_test: 25
# prob: 1.0  class: 13 y_test: 13
#      prob: 1.34605e-19  class: 12 y_test: 13
#      prob: 1.00386e-19  class: 38 y_test: 13
#      prob: 8.15328e-20  class: 15 y_test: 13
#      prob: 3.75704e-22  class: 35 y_test: 13
# prob: 0.999976  class: 10 y_test: 10
#      prob: 2.11973e-05  class: 9 y_test: 10
#      prob: 1.65286e-06  class: 7 y_test: 10
#      prob: 5.80376e-07  class: 5 y_test: 10
#      prob: 1.42199e-07  class: 23 y_test: 10
# prob: 0.999876  class: 5 y_test: 5
#      prob: 0.000101099  class: 2 y_test: 5
#      prob: 1.99188e-05  class: 3 y_test: 5
#      prob: 1.61325e-06  class: 7 y_test: 5
#      prob: 8.38496e-07  class: 1 y_test: 5
# prob: 0.99997  class: 4 y_test: 4
#      prob: 2.55655e-05  class: 1 y_test: 4
#      prob: 3.03275e-06  class: 8 y_test: 4
#      prob: 5.87022e-07  class: 2 y_test: 4
#      prob: 3.73304e-07  class: 0 y_test: 4
# prob: 0.999903  class: 10 y_test: 10
#      prob: 9.62296e-05  class: 9 y_test: 10
#      prob: 9.3395e-07  class: 7 y_test: 10
#      prob: 4.35125e-08  class: 5 y_test: 10
#      prob: 1.97743e-08  class: 40 y_test: 10
# prob: 0.999989  class: 2 y_test: 2
#      prob: 8.28052e-06  class: 5 y_test: 2
#      prob: 1.42553e-06  class: 1 y_test: 2
#      prob: 7.81098e-07  class: 7 y_test: 2
#      prob: 3.27001e-07  class: 3 y_test: 2
# prob: 0.999997  class: 4 y_test: 4
#      prob: 1.47248e-06  class: 1 y_test: 4
#      prob: 1.16513e-06  class: 0 y_test: 4
#      prob: 2.05607e-10  class: 8 y_test: 4
#      prob: 1.9024e-10  class: 2 y_test: 4
# prob: 0.877007  class: 5 y_test: 5
#      prob: 0.0498164  class: 7 y_test: 5
#      prob: 0.0447104  class: 2 y_test: 5
#      prob: 0.0162347  class: 3 y_test: 5
#      prob: 0.00639786  class: 1 y_test: 5
# prob: 0.999908  class: 1 y_test: 1
#      prob: 8.76622e-05  class: 0 y_test: 1
#      prob: 4.76332e-06  class: 2 y_test: 1
#      prob: 5.52177e-08  class: 6 y_test: 1
#      prob: 1.41903e-08  class: 4 y_test: 1
# prob: 1.0  class: 14 y_test: 14
#      prob: 1.22309e-07  class: 38 y_test: 14
#      prob: 7.79562e-08  class: 15 y_test: 14
#      prob: 2.54599e-08  class: 39 y_test: 14
#      prob: 1.02937e-08  class: 33 y_test: 14
# prob: 0.996556  class: 12 y_test: 12
#      prob: 0.00320322  class: 42 y_test: 12
#      prob: 0.000198045  class: 40 y_test: 12
#      prob: 2.40933e-05  class: 41 y_test: 12
#      prob: 1.57737e-05  class: 11 y_test: 12
# prob: 1.0  class: 12 y_test: 12
#      prob: 1.26145e-08  class: 40 y_test: 12
#      prob: 1.15128e-09  class: 7 y_test: 12
#      prob: 1.39622e-12  class: 8 y_test: 12
#      prob: 5.63471e-13  class: 9 y_test: 12
# prob: 0.999979  class: 5 y_test: 5
#      prob: 1.61626e-05  class: 3 y_test: 5
#      prob: 4.1246e-06  class: 2 y_test: 5
#      prob: 4.2893e-07  class: 1 y_test: 5
# ...
#      prob: 3.40864e-05  class: 42 y_test: 6
#      prob: 2.09401e-07  class: 1 y_test: 6
#      prob: 1.68924e-09  class: 41 y_test: 6
# prob: 0.999992  class: 12 y_test: 12
#      prob: 7.72642e-06  class: 40 y_test: 12
#      prob: 6.56324e-08  class: 7 y_test: 12
#      prob: 2.59241e-08  class: 11 y_test: 12
#      prob: 1.36043e-08  class: 17 y_test: 12
# prob: 0.998542  class: 16 y_test: 16
#      prob: 0.00141508  class: 9 y_test: 16
#      prob: 1.81885e-05  class: 7 y_test: 16
#      prob: 1.4836e-05  class: 10 y_test: 16
#      prob: 5.02541e-06  class: 3 y_test: 16
# prob: 0.99962  class: 3 y_test: 3
#      prob: 0.000378926  class: 5 y_test: 3
#      prob: 1.37093e-06  class: 2 y_test: 3
#      prob: 4.76475e-11  class: 7 y_test: 3
#      prob: 2.53183e-11  class: 1 y_test: 3
# prob: 0.999838  class: 35 y_test: 35
#      prob: 8.69345e-05  class: 10 y_test: 35
#      prob: 4.49201e-05  class: 33 y_test: 35
#      prob: 2.89221e-05  class: 9 y_test: 35
#      prob: 1.18632e-06  class: 3 y_test: 35
# prob: 0.99996  class: 1 y_test: 1
#      prob: 3.88861e-05  class: 2 y_test: 1
#      prob: 4.64163e-07  class: 5 y_test: 1
#      prob: 3.95818e-07  class: 0 y_test: 1
#      prob: 9.81057e-09  class: 4 y_test: 1
# prob: 0.999922  class: 9 y_test: 9
#      prob: 7.21933e-05  class: 16 y_test: 9
#      prob: 2.8549e-06  class: 12 y_test: 9
#      prob: 1.88435e-06  class: 10 y_test: 9
#      prob: 7.62831e-07  class: 7 y_test: 9
# prob: 0.957417  class: 7 y_test: 7
#      prob: 0.0293112  class: 5 y_test: 7
#      prob: 0.0127783  class: 2 y_test: 7
#      prob: 0.000463735  class: 8 y_test: 7
#      prob: 1.16511e-05  class: 1 y_test: 7
# prob: 0.98473  class: 8 y_test: 8
#      prob: 0.0152672  class: 7 y_test: 8
#      prob: 2.42093e-06  class: 40 y_test: 8
#      prob: 3.1697e-07  class: 12 y_test: 8
#      prob: 2.18201e-07  class: 2 y_test: 8
# HIT (0, 12563)
# prob: 0.278438  class: 23 y_test: 30
#      prob: 0.17328  class: 30 y_test: 30
#      prob: 0.168139  class: 31 y_test: 30
#      prob: 0.15614  class: 21 y_test: 30
#      prob: 0.0528833  class: 28 y_test: 30
# prob: 0.999999  class: 23 y_test: 23
#      prob: 5.31266e-07  class: 19 y_test: 23
#      prob: 1.91133e-08  class: 30 y_test: 23
#      prob: 8.15433e-09  class: 11 y_test: 23
#      prob: 3.83734e-09  class: 21 y_test: 23
# prob: 0.999994  class: 2 y_test: 2
#      prob: 2.76508e-06  class: 1 y_test: 2
#      prob: 1.88803e-06  class: 5 y_test: 2
#      prob: 1.20305e-06  class: 3 y_test: 2
#      prob: 8.19763e-08  class: 7 y_test: 2
# prob: 0.999996  class: 39 y_test: 39
#      prob: 3.91898e-06  class: 33 y_test: 39
#      prob: 2.58628e-08  class: 37 y_test: 39
#      prob: 9.65891e-09  class: 4 y_test: 39
#      prob: 8.81045e-10  class: 14 y_test: 39
# prob: 0.988751  class: 23 y_test: 23
#      prob: 0.0109666  class: 19 y_test: 23
#      prob: 0.00012717  class: 20 y_test: 23
#      prob: 6.15956e-05  class: 31 y_test: 23
#      prob: 4.72566e-05  class: 21 y_test: 23
# prob: 0.999897  class: 10 y_test: 10
#      prob: 7.71287e-05  class: 9 y_test: 10
#      prob: 1.49251e-05  class: 7 y_test: 10
#      prob: 1.03113e-05  class: 5 y_test: 10
#      prob: 6.62084e-07  class: 42 y_test: 10
# HIT (0, 12569)
# prob: 0.923923  class: 30 y_test: 11
#      prob: 0.0411935  class: 11 y_test: 11
#      prob: 0.0229832  class: 24 y_test: 11
#      prob: 0.00531404  class: 25 y_test: 11
#      prob: 0.00187206  class: 28 y_test: 11
# prob: 0.999618  class: 1 y_test: 1
#      prob: 0.000377009  class: 0 y_test: 1
#      prob: 4.06097e-06  class: 2 y_test: 1
#      prob: 3.68517e-07  class: 4 y_test: 1
#      prob: 2.60037e-07  class: 6 y_test: 1
# prob: 0.999996  class: 2 y_test: 2
#      prob: 2.41898e-06  class: 5 y_test: 2
#      prob: 1.31106e-06  class: 1 y_test: 2
#      prob: 7.03062e-08  class: 3 y_test: 2
#      prob: 2.45972e-08  class: 7 y_test: 2
# prob: 0.621207  class: 15 y_test: 15
#      prob: 0.23458  class: 13 y_test: 15
#      prob: 0.136175  class: 34 y_test: 15
#      prob: 0.00460527  class: 35 y_test: 15
#      prob: 0.00208769  class: 14 y_test: 15
# prob: 0.995686  class: 17 y_test: 17
#      prob: 0.00385244  class: 14 y_test: 17
#      prob: 0.000220314  class: 38 y_test: 17
#      prob: 0.000120577  class: 8 y_test: 17
#      prob: 6.05918e-05  class: 40 y_test: 17
# prob: 0.999875  class: 7 y_test: 7
#      prob: 0.000117441  class: 8 y_test: 7
#      prob: 7.1437e-06  class: 5 y_test: 7
#      prob: 4.77944e-08  class: 2 y_test: 7
#      prob: 3.02971e-08  class: 1 y_test: 7
# prob: 0.998942  class: 2 y_test: 2
#      prob: 0.00103234  class: 1 y_test: 2
#      prob: 2.18042e-05  class: 5 y_test: 2
#      prob: 2.43268e-06  class: 7 y_test: 2
#      prob: 9.22461e-07  class: 4 y_test: 2
# prob: 0.99925  class: 18 y_test: 18
#      prob: 0.000428999  class: 27 y_test: 18
#      prob: 0.000313378  class: 26 y_test: 18
#      prob: 7.55341e-06  class: 24 y_test: 18
#      prob: 7.14418e-08  class: 28 y_test: 18
# prob: 0.999333  class: 11 y_test: 11
#      prob: 0.000339636  class: 30 y_test: 11
#      prob: 0.000166602  class: 27 y_test: 11
#      prob: 7.15511e-05  class: 21 y_test: 11
#      prob: 7.15115e-05  class: 40 y_test: 11
# prob: 0.999997  class: 9 y_test: 9
#      prob: 3.48928e-06  class: 16 y_test: 9
#      prob: 2.35233e-09  class: 3 y_test: 9
#      prob: 6.00202e-10  class: 10 y_test: 9
#      prob: 2.72226e-10  class: 12 y_test: 9
# prob: 0.622028  class: 20 y_test: 20
#      prob: 0.229736  class: 27 y_test: 20
#      prob: 0.104898  class: 23 y_test: 20
#      prob: 0.0363962  class: 11 y_test: 20
#      prob: 0.00479123  class: 28 y_test: 20
# prob: 0.999955  class: 2 y_test: 2
#      prob: 4.48407e-05  class: 5 y_test: 2
#      prob: 5.59785e-08  class: 7 y_test: 2
#      prob: 3.68679e-08  class: 1 y_test: 2
#      prob: 2.02504e-08  class: 3 y_test: 2
# prob: 0.999999  class: 9 y_test: 9
#      prob: 7.41547e-07  class: 10 y_test: 9
#      prob: 1.28714e-07  class: 16 y_test: 9
#      prob: 7.14036e-09  class: 3 y_test: 9
#      prob: 6.65596e-10  class: 12 y_test: 9
# prob: 0.988518  class: 3 y_test: 3
#      prob: 0.0113902  class: 5 y_test: 3
#      prob: 5.17844e-05  class: 2 y_test: 3
#      prob: 3.02788e-05  class: 7 y_test: 3
#      prob: 4.33816e-06  class: 1 y_test: 3
# prob: 0.998732  class: 1 y_test: 1
#      prob: 0.00124645  class: 2 y_test: 1
#      prob: 1.64341e-05  class: 0 y_test: 1
#      prob: 4.2123e-06  class: 4 y_test: 1
#      prob: 8.50323e-07  class: 5 y_test: 1
# prob: 1.0  class: 11 y_test: 11
#      prob: 1.31163e-07  class: 30 y_test: 11
#      prob: 2.70799e-09  class: 21 y_test: 11
#      prob: 8.42234e-11  class: 27 y_test: 11
#      prob: 2.29808e-12  class: 23 y_test: 11
# prob: 0.93214  class: 8 y_test: 8
#      prob: 0.0370464  class: 4 y_test: 8
#      prob: 0.0178661  class: 7 y_test: 8
#      prob: 0.0113798  class: 2 y_test: 8
#      prob: 0.000947134  class: 15 y_test: 8
# prob: 0.999999  class: 10 y_test: 10
#      prob: 8.38161e-07  class: 5 y_test: 10
#      prob: 3.31016e-07  class: 7 y_test: 10
#      prob: 1.4265e-07  class: 9 y_test: 10
#      prob: 1.74854e-08  class: 42 y_test: 10
# prob: 0.999676  class: 6 y_test: 6
#      prob: 0.000208047  class: 32 y_test: 6
#      prob: 0.000108254  class: 42 y_test: 6
#      prob: 8.06038e-06  class: 1 y_test: 6
#      prob: 4.15519e-08  class: 41 y_test: 6
# prob: 0.999986  class: 10 y_test: 10
#      prob: 1.01556e-05  class: 9 y_test: 10
#      prob: 1.76326e-06  class: 5 y_test: 10
#      prob: 1.45752e-06  class: 7 y_test: 10
#      prob: 2.0184e-07  class: 2 y_test: 10
# prob: 0.989429  class: 3 y_test: 3
#      prob: 0.0105489  class: 5 y_test: 3
#      prob: 2.16058e-05  class: 2 y_test: 3
#      prob: 6.00982e-08  class: 7 y_test: 3
#      prob: 3.58697e-08  class: 10 y_test: 3
# prob: 0.999997  class: 25 y_test: 25
#      prob: 3.18098e-06  class: 20 y_test: 25
#      prob: 5.25861e-08  class: 29 y_test: 25
#      prob: 6.74458e-09  class: 22 y_test: 25
#      prob: 4.50131e-09  class: 23 y_test: 25
# prob: 0.999726  class: 5 y_test: 5
#      prob: 0.000143536  class: 3 y_test: 5
#      prob: 0.000106825  class: 2 y_test: 5
#      prob: 1.87195e-05  class: 7 y_test: 5
#      prob: 4.64579e-06  class: 10 y_test: 5
# prob: 0.997236  class: 22 y_test: 22
#      prob: 0.00145261  class: 26 y_test: 22
#      prob: 0.000914016  class: 29 y_test: 22
#      prob: 0.00013962  class: 25 y_test: 22
#      prob: 0.00011207  class: 18 y_test: 22
# prob: 0.9897  class: 3 y_test: 3
#      prob: 0.00814488  class: 5 y_test: 3
#      prob: 0.00214617  class: 2 y_test: 3
#      prob: 6.32402e-06  class: 7 y_test: 3
#      prob: 1.63188e-06  class: 1 y_test: 3
# prob: 1.0  class: 12 y_test: 12
#      prob: 1.19349e-07  class: 7 y_test: 12
#      prob: 1.75589e-08  class: 8 y_test: 12
#      prob: 2.36627e-09  class: 40 y_test: 12
#      prob: 1.71192e-11  class: 9 y_test: 12
# prob: 1.0  class: 25 y_test: 25
#      prob: 9.6288e-09  class: 20 y_test: 25
#      prob: 1.30273e-11  class: 29 y_test: 25
#      prob: 3.94673e-12  class: 22 y_test: 25
#      prob: 4.36679e-13  class: 23 y_test: 25
# prob: 1.0  class: 13 y_test: 13
#      prob: 8.33786e-09  class: 15 y_test: 13
#      prob: 2.35457e-10  class: 12 y_test: 13
#      prob: 1.67812e-10  class: 35 y_test: 13
#      prob: 1.67107e-10  class: 38 y_test: 13
# prob: 0.999994  class: 10 y_test: 10
#      prob: 3.48096e-06  class: 9 y_test: 10
#      prob: 2.41082e-06  class: 7 y_test: 10
#      prob: 1.08827e-07  class: 40 y_test: 10
#      prob: 8.56251e-09  class: 5 y_test: 10
# prob: 1.0  class: 35 y_test: 35
#      prob: 5.82179e-09  class: 9 y_test: 35
#      prob: 3.51316e-09  class: 10 y_test: 35
#      prob: 2.45305e-09  class: 3 y_test: 35
#      prob: 1.239e-09  class: 33 y_test: 35
# prob: 0.999954  class: 10 y_test: 10
#      prob: 3.66505e-05  class: 5 y_test: 10
#      prob: 6.92324e-06  class: 9 y_test: 10
#      prob: 9.28005e-07  class: 7 y_test: 10
#      prob: 8.3652e-07  class: 42 y_test: 10
# prob: 1.0  class: 35 y_test: 35
#      prob: 7.51192e-10  class: 33 y_test: 35
#      prob: 7.73618e-11  class: 3 y_test: 35
#      prob: 1.36102e-11  class: 34 y_test: 35
#      prob: 4.07593e-13  class: 36 y_test: 35
# prob: 1.0  class: 38 y_test: 38
#      prob: 5.57073e-10  class: 34 y_test: 38
#      prob: 1.23088e-12  class: 14 y_test: 38
#      prob: 1.07133e-13  class: 13 y_test: 38
#      prob: 4.0316e-14  class: 36 y_test: 38
# HIT (0, 12602)
# prob: 0.624677  class: 29 y_test: 24
#      prob: 0.194025  class: 24 y_test: 24
#      prob: 0.0795797  class: 28 y_test: 24
#      prob: 0.0720186  class: 25 y_test: 24
#      prob: 0.0133957  class: 22 y_test: 24
# prob: 1.0  class: 13 y_test: 13
#      prob: 8.66585e-14  class: 38 y_test: 13
#      prob: 4.92777e-14  class: 12 y_test: 13
#      prob: 6.53175e-15  class: 15 y_test: 13
#      prob: 1.76073e-17  class: 35 y_test: 13
# prob: 0.999052  class: 35 y_test: 35
#      prob: 0.00061432  class: 33 y_test: 35
#      prob: 0.000239993  class: 13 y_test: 35
#      prob: 5.32378e-05  class: 34 y_test: 35
#      prob: 2.3344e-05  class: 15 y_test: 35
# prob: 0.999993  class: 25 y_test: 25
#      prob: 6.46904e-06  class: 20 y_test: 25
#      prob: 1.0169e-07  class: 23 y_test: 25
#      prob: 9.50781e-08  class: 30 y_test: 25
#      prob: 3.19934e-08  class: 24 y_test: 25
# prob: 1.0  class: 38 y_test: 38
#      prob: 9.57363e-10  class: 34 y_test: 38
#      prob: 5.36685e-13  class: 40 y_test: 38
#      prob: 1.22506e-13  class: 14 y_test: 38
#      prob: 7.55709e-14  class: 36 y_test: 38
# prob: 0.999992  class: 1 y_test: 1
#      prob: 6.8581e-06  class: 0 y_test: 1
#      prob: 7.22775e-07  class: 4 y_test: 1
#      prob: 6.25701e-08  class: 2 y_test: 1
#      prob: 1.04132e-09  class: 5 y_test: 1
# prob: 0.800831  class: 18 y_test: 18
#      prob: 0.0722872  class: 27 y_test: 18
#      prob: 0.0689201  class: 26 y_test: 18
#      prob: 0.046829  class: 24 y_test: 18
#      prob: 0.00821953  class: 20 y_test: 18
# prob: 0.999476  class: 7 y_test: 7
#      prob: 0.000371107  class: 5 y_test: 7
#      prob: 7.77202e-05  class: 40 y_test: 7
#      prob: 4.04195e-05  class: 10 y_test: 7
#      prob: 2.02407e-05  class: 8 y_test: 7
# prob: 0.999915  class: 35 y_test: 35
#      prob: 8.09771e-05  class: 3 y_test: 35
#      prob: 1.91764e-06  class: 9 y_test: 35
#      prob: 1.13999e-06  class: 33 y_test: 35
#      prob: 6.81117e-07  class: 34 y_test: 35
# prob: 0.999998  class: 11 y_test: 11
#      prob: 1.22551e-06  class: 30 y_test: 11
#      prob: 2.47955e-07  class: 21 y_test: 11
#      prob: 9.02848e-08  class: 27 y_test: 11
#      prob: 7.86519e-09  class: 40 y_test: 11
# prob: 0.999993  class: 39 y_test: 39
#      prob: 7.14623e-06  class: 33 y_test: 39
#      prob: 5.64095e-08  class: 37 y_test: 39
#      prob: 5.8793e-09  class: 4 y_test: 39
#      prob: 5.23074e-10  class: 14 y_test: 39
# prob: 0.97478  class: 8 y_test: 8
#      prob: 0.025139  class: 7 y_test: 8
#      prob: 2.43211e-05  class: 5 y_test: 8
#      prob: 1.88593e-05  class: 2 y_test: 8
#      prob: 1.52951e-05  class: 4 y_test: 8
# HIT (0, 12614)
# prob: 0.967712  class: 4 y_test: 0
#      prob: 0.0209134  class: 0 y_test: 0
#      prob: 0.00653265  class: 1 y_test: 0
#      prob: 0.00481988  class: 8 y_test: 0
#      prob: 7.82169e-06  class: 15 y_test: 0
# prob: 0.99967  class: 10 y_test: 10
#      prob: 0.000225443  class: 23 y_test: 10
#      prob: 8.08316e-05  class: 5 y_test: 10
#      prob: 1.47508e-05  class: 42 y_test: 10
#      prob: 7.70176e-06  class: 9 y_test: 10
# HIT (0, 12616)
# prob: 0.740391  class: 19 y_test: 18
#      prob: 0.069645  class: 9 y_test: 18
#      prob: 0.0497503  class: 26 y_test: 18
#      prob: 0.0299564  class: 39 y_test: 18
#      prob: 0.0227067  class: 37 y_test: 18
# prob: 0.982791  class: 31 y_test: 31
#      prob: 0.0133143  class: 21 y_test: 31
#      prob: 0.00374463  class: 19 y_test: 31
#      prob: 0.00014301  class: 23 y_test: 31
#      prob: 6.80707e-06  class: 29 y_test: 31
# prob: 0.999461  class: 8 y_test: 8
#      prob: 0.000537643  class: 7 y_test: 8
#      prob: 1.26252e-06  class: 4 y_test: 8
#      prob: 2.50254e-07  class: 1 y_test: 8
#      prob: 2.38915e-08  class: 2 y_test: 8
# prob: 0.927868  class: 31 y_test: 31
#      prob: 0.0679054  class: 21 y_test: 31
#      prob: 0.00352085  class: 19 y_test: 31
#      prob: 0.000641979  class: 23 y_test: 31
#      prob: 2.33994e-05  class: 29 y_test: 31
# prob: 1.0  class: 13 y_test: 13
#      prob: 4.98823e-09  class: 12 y_test: 13
#      prob: 3.38883e-09  class: 35 y_test: 13
#      prob: 1.35881e-09  class: 9 y_test: 13
#      prob: 1.26823e-09  class: 15 y_test: 13
# prob: 0.999225  class: 5 y_test: 5
#      prob: 0.000632625  class: 7 y_test: 5
#      prob: 4.91998e-05  class: 2 y_test: 5
#      prob: 4.90713e-05  class: 3 y_test: 5
#      prob: 3.33802e-05  class: 1 y_test: 5
# prob: 1.0  class: 12 y_test: 12
#      prob: 4.31231e-09  class: 40 y_test: 12
#      prob: 1.02458e-11  class: 7 y_test: 12
#      prob: 4.59389e-13  class: 17 y_test: 12
#      prob: 2.57176e-13  class: 9 y_test: 12
# prob: 0.999997  class: 35 y_test: 35
#      prob: 1.98838e-06  class: 33 y_test: 35
#      prob: 7.55566e-07  class: 10 y_test: 35
#      prob: 7.81983e-08  class: 9 y_test: 35
#      prob: 6.00739e-08  class: 3 y_test: 35
# prob: 0.999521  class: 25 y_test: 25
#      prob: 0.00028244  class: 24 y_test: 25
#      prob: 0.000162535  class: 20 y_test: 25
#      prob: 3.06776e-05  class: 30 y_test: 25
#      prob: 1.24035e-06  class: 29 y_test: 25
# prob: 1.0  class: 12 y_test: 12
#      prob: 5.27727e-10  class: 40 y_test: 12
#      prob: 5.07506e-12  class: 7 y_test: 12
#      prob: 3.33291e-15  class: 42 y_test: 12
#      prob: 2.3908e-15  class: 11 y_test: 12
# prob: 1.0  class: 33 y_test: 33
#      prob: 1.09199e-09  class: 39 y_test: 33
#      prob: 3.95632e-12  class: 37 y_test: 33
#      prob: 1.54314e-13  class: 35 y_test: 33
#      prob: 5.1458e-14  class: 17 y_test: 33
# HIT (0, 12627)
# prob: 0.614075  class: 12 y_test: 6
#      prob: 0.114105  class: 5 y_test: 6
#      prob: 0.0666652  class: 32 y_test: 6
#      prob: 0.0543832  class: 8 y_test: 6
#      prob: 0.0536944  class: 7 y_test: 6
# prob: 0.97642  class: 7 y_test: 7
#      prob: 0.0190332  class: 8 y_test: 7
#      prob: 0.00269832  class: 5 y_test: 7
#      prob: 0.00113385  class: 2 y_test: 7
#      prob: 0.000541638  class: 1 y_test: 7
# prob: 0.984168  class: 10 y_test: 10
#      prob: 0.010602  class: 2 y_test: 10
#      prob: 0.0042496  class: 37 y_test: 10
#      prob: 0.000416304  class: 5 y_test: 10
#      prob: 0.000248081  class: 9 y_test: 10
# 855

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# Take several pictures of traffic signs that you find on the web or around you (at least five), and run them through your classifier on your computer to produce example results. The classifier might not recognize some local signs but it could prove interesting nonetheless.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Implementation
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project. Once you have completed your implementation and are satisfied with the results, be sure to thoroughly answer the questions that follow.

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.
import matplotlib.image as mpimg
import os

imgs_path = os.getcwd()+'/images/'
labels=[2]
imgs = os.listdir(imgs_path)
imgs_list = []

#does x fuck with the x placeholder in TF? Of course it does. Change to xx. 
#one would think a loop variable would have a separate scope. But no. 
for xx in imgs:
    print('xx:',xx, 'fileext:', os.path.splitext(xx)[1])
    if(xx !='.DS_Store' and (os.path.splitext(xx)[1]=='.jpg' or os.path.splitext(xx)[1]=='.jpeg')):
        print ('processing xx:',xx)
        image = mpimg.imread(imgs_path+xx)
        print ('image.shape ',image.shape)
        small=cv2.resize(image,(32,32))
        imgs_list.append(small)
        print ('small.shape: ',small.shape)
        plt.imshow(small)
        plt.show()
    
X_OUTSIDE_IMAGE = np.array(imgs_list)
X_OUTSIDE_pp = preprocess(X_OUTSIDE_IMAGE,version=0)
X_OUTSIDE_pp_format=X_OUTSIDE_pp[...,newaxis]
#X_OUTSIDE_pp_format=X_OUTSIDE_pp_format.astype(np.float32)
print ('X_OUTSIDE_process shape', X_OUTSIDE_pp.shape)
print ('X_OUTSIDE shape',X_OUTSIDE_pp_format.shape)
print (X_OUTSIDE_pp_format.dtype)
# Out:
# xx: .DS_Store fileext:
# xx: 20_km-h.jpg fileext: .jpg
# processing xx: 20_km-h.jpg
# image.shape  (2368, 3552, 3)
# small.shape:  (32, 32, 3)
# xx: 20km.jpeg fileext: .jpeg
# processing xx: 20km.jpeg
# image.shape  (225, 225, 3)
# small.shape:  (32, 32, 3)
# xx: 20km_white.png fileext: .png
# xx: 20km_whiteblackline.png fileext: .png
# xx: 20kmbrick.png fileext: .png
# xx: 30-kph-sign.jpg fileext: .jpg
# processing xx: 30-kph-sign.jpg
# image.shape  (391, 655, 3)
# small.shape:  (32, 32, 3)
# xx: 30km.png fileext: .png
# xx: one fileext:
# X_OUTSIDE_process shape (3, 32, 32)
# X_OUTSIDE shape (3, 32, 32, 1)
# float32

# %%
plt.imshow(X_OUTSIDE_pp[0],cmap='gray')
print(X_OUTSIDE_pp_format.shape)
# Out:
# (3, 32, 32, 1)

# %% [markdown]
# ### Question 6
#
# _Choose five candidate images of traffic signs and provide them in the report. Are there any particular qualities of the image(s) that might make classification difficult? It could be helpful to plot the images in the notebook._

# %% [markdown]
# **Answer:**

# %%
### Visualize the softmax probabilities here.
### Feel free to use as many code cells as needed.
#for 1 image this is redundant we have this built into the cell above this

#print (top_k_vals)
for x in range( len(top_k_idxs[0])):
    print ('prob:',top_k_vals[0][x],' class:',csv_dict[top_k_idxs[0][x]])
# Out:
# prob: 1.0  class: Vehicles over 3.5 metric tons prohibited
# prob: 1.42503e-07  class: No passing
# prob: 1.91368e-08  class: No passing for vehicles over 3.5 metric tons
# prob: 4.24124e-12  class: Speed limit (100km/h)
# prob: 1.552e-12  class: Speed limit (80km/h)

# %%
#
testMe=[]
testMe.extend(X_OUTSIDE_pp_format)
T_test=np.array(testMe)
labels=np.array([0,0,1])
print('T_test shape:',T_test.shape)

#
with tf.Session() as sess:
    saver.restore(sess, save_path )
    softmax = tf.nn.softmax(logits)
    #classes = sess.run(tf.argmax(logits, 1), feed_dict={x: T_test, keep_prob : 1.0})
    top_k_val, top_k_idx = tf.nn.top_k(softmax, k=5)   
    top_k_vals, top_k_idxs = sess.run([top_k_val, top_k_idx], feed_dict={x: T_test, keep_prob : 1.0})
# Out:
# T_test shape: (3, 32, 32, 1)

# %%
for y in range(top_k_idxs.shape[0]):
    for x in range(len(top_k_idxs[0])):
        #print ('x:',x, 'y:',y)
        if(x==0 and (labels[y]!=top_k_idxs[y][x])):
            print ('Mismatch..' ,(x,y))
            numHit.append((x,y))
        if x==0:
            print ('prob:', top_k_vals[y][x],' class:',top_k_idxs[y][x], 'labels:',labels[y])
        else:
            print ('     prob:', top_k_vals[y][x],' class:',top_k_idxs[y][x], 'labels:',y_test[y])
# Out:
# prob: 0.611191  class: 0 labels: 0
#      prob: 0.386009  class: 1 labels: 16
#      prob: 0.00258816  class: 4 labels: 16
#      prob: 0.000156978  class: 5 labels: 16
#      prob: 4.90765e-05  class: 14 labels: 16
# Mismatch.. (0, 1)
# prob: 0.492484  class: 1 labels: 0
#      prob: 0.447796  class: 0 labels: 1
#      prob: 0.0582518  class: 5 labels: 1
#      prob: 0.00126234  class: 6 labels: 1
#      prob: 0.000192473  class: 4 labels: 1
# Mismatch.. (0, 2)
# prob: 0.187051  class: 11 labels: 1
#      prob: 0.163909  class: 42 labels: 38
#      prob: 0.135078  class: 41 labels: 38
#      prob: 0.124886  class: 12 labels: 38
#      prob: 0.0599692  class: 40 labels: 38

# %%
### Visualize the softmax probabilities here.
### Feel free to use as many code cells as needed.
with tf.Session() as sess:
    predicts = sess.run(tf.nn.top_k(classes, k=5, sorted=True))
    print(predicts)
    
print (predicts)
for i in range(len(predicts[0])):
    print('probabilities:', predicts[0][i], 'classes:', predicts[1][i])
# Out:
# TopKV2(values=array([1, 1, 1]), indices=array([0, 1, 2], dtype=int32))
# TopKV2(values=array([1, 1, 1]), indices=array([0, 1, 2], dtype=int32))
# probabilities: 1 classes: 0
# probabilities: 1 classes: 1
# probabilities: 1 classes: 2

# %% [markdown]
# ### Question 7
#
# _Is your model able to perform equally well on captured pictures when compared to testing on the dataset? The simplest way to do this check the accuracy of the predictions. For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate._
#
# _**NOTE:** You could check the accuracy manually by using `signnames.csv` (same directory). This file has a mapping from the class id (0-42) to the corresponding sign name. So, you could take the class id the model outputs, lookup the name in `signnames.csv` and see if it matches the sign from the image._

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Question 8
#
# *Use the model's softmax probabilities to visualize the **certainty** of its predictions, [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here. Which predictions is the model certain of? Uncertain? If the model was incorrect in its initial prediction, does the correct prediction appear in the top k? (k should be 5 at most)*
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %% [markdown]
# **Answer:**

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %%
import os
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout,Convolution2D,MaxPooling2D,Flatten
from keras.optimizers import Adam


# number of classes
nb_classes = 43
# input image dimensions
img_rows, img_cols, img_ch = 32, 32, 3
# number of convolutional filters to use
nb_filter1 = 32
nb_filter2 = 64
nb_filter3 = 128
# size of pooling area for max pooling
pool_size = (2, 2)
pool_strides = (1,1)
# convolution kernel size
kernel_size = (5, 5)
# number of hidden units in the first fully connected layer
nb_fc1=128
nb_fc2=128


model = Sequential()
model.add(Convolution2D(nb_filter1, kernel_size[0], kernel_size[1],border_mode='same', subsample=(1,1),
                        input_shape=(img_rows,img_cols,img_ch),name='conv1'))
model.add(Activation('relu',name='relu1'))
model.add(MaxPooling2D(pool_size=pool_size,strides=pool_strides,name='maxpool1'))
model.add(Convolution2D(nb_filter2, kernel_size[0], kernel_size[1],border_mode='same',subsample=(1,1),
                        name='conv2'))
model.add(Activation('relu',name='relu2'))
model.add(MaxPooling2D(pool_size=pool_size,strides=None,name='maxpool2'))
model.add(Convolution2D(nb_filter2, kernel_size[0], kernel_size[1],border_mode='same',subsample=(1,1),
                        name='conv3'))
model.add(Activation('relu',name='relu3'))
model.add(MaxPooling2D(pool_size=pool_size,strides=None,name='maxpool3'))
model.add(Flatten(name='flatten'))
model.add(Dropout(0.5,name='dropout1'))
model.add(Dense(nb_fc1, name='hidden1'))
model.add(Activation('relu',name='relu4'))
model.add(Dropout(0.5,name='dropout2'))
model.add(Dense(nb_fc2,  name='hidden2'))
model.add(Activation('relu',name='relu5'))
model.add(Dense(nb_classes, name='output'))
model.add(Activation('softmax',name='softmax'))

model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# conv1 (Convolution2D)            (None, 32, 32, 32)    2432        convolution2d_input_2[0][0]
# ____________________________________________________________________________________________________
# relu1 (Activation)               (None, 32, 32, 32)    0           conv1[0][0]
# ____________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)          (None, 31, 31, 32)    0           relu1[0][0]
# ____________________________________________________________________________________________________
# conv2 (Convolution2D)            (None, 31, 31, 64)    51264       maxpool1[0][0]
# ____________________________________________________________________________________________________
# relu2 (Activation)               (None, 31, 31, 64)    0           conv2[0][0]
# ____________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)          (None, 15, 15, 64)    0           relu2[0][0]
# ____________________________________________________________________________________________________
# conv3 (Convolution2D)            (None, 15, 15, 64)    102464      maxpool2[0][0]
# ____________________________________________________________________________________________________
# relu3 (Activation)               (None, 15, 15, 64)    0           conv3[0][0]
# ____________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)          (None, 7, 7, 64)      0           relu3[0][0]
# ____________________________________________________________________________________________________
# flatten (Flatten)                (None, 3136)          0           maxpool3[0][0]
# ____________________________________________________________________________________________________
# dropout1 (Dropout)               (None, 3136)          0           flatten[0][0]
# ____________________________________________________________________________________________________
# hidden1 (Dense)                  (None, 128)           401536      dropout1[0][0]
# ____________________________________________________________________________________________________
# relu4 (Activation)               (None, 128)           0           hidden1[0][0]
# ____________________________________________________________________________________________________
# dropout2 (Dropout)               (None, 128)           0           relu4[0][0]
# ____________________________________________________________________________________________________
# hidden2 (Dense)                  (None, 128)           16512       dropout2[0][0]
# ____________________________________________________________________________________________________
# relu5 (Activation)               (None, 128)           0           hidden2[0][0]
# ____________________________________________________________________________________________________
# output (Dense)                   (None, 43)            5547        relu5[0][0]
# ____________________________________________________________________________________________________
# softmax (Activation)             (None, 43)            0           output[0][0]
# ====================================================================================================
# Total params: 579,755
# Trainable params: 579,755
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
def normalize_images(X):
    """
    Normalize the image data with Min-Max scaling to a range of [-0.5, 0.5]
    :param image_data: The image data to be normalized
    :return: Normalized image data
    """
    a = -0.5;b = 0.5; Xmin = 0.0;Xmax = 255.0;
    Xm=np.mean(X)
    Xp = X - Xm
    Xmin=np.min(Xp)
    Xmax=np.max(Xp)
    Xp = a + (Xp-Xmin)*(b-a)/(Xmax-Xmin)
    return Xp

X_train = normalize_images(X_train)
X_test = normalize_images(X_test)
X_valid = normalize_images(X_valid)

# one-hot encoding of labels
def to_categorical(y, nb_classes=None):
    '''Convert class vector (integers from 0 to nb_classes) to binary class matrix, for use with categorical_crossentropy.
    # Arguments
        y: class vector to be converted into a matrix
        nb_classes: total number of classes
    # Returns
        A binary matrix representation of the input.
    '''
    y = np.array(y, dtype='int')
    if not nb_classes:
        nb_classes = np.max(y)+1
    Y = np.zeros((len(y), nb_classes))
    for i in range(len(y)):
        Y[i, y[i]] = 1.
    return Y

y_train = to_categorical(y_train)
y_test  = to_categorical(y_test)
y_valid = to_categorical(y_valid)

# %%
nb_epoch = 1000
batch_size=128

model_name='models/TrafficSigns_3conv_3pool_2dropout.ckpt'

if os.path.isfile(model_name):
    try:
        model = load_model(model_name)
        print('loading trained model ...')
    except Exception as e:
        print('Unable to load model', model_name, ':', e)
        raise    


adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam,
          loss='categorical_crossentropy',
          metrics=['accuracy'])

history = model.fit(X_train, y_train,
                    batch_size=batch_size, nb_epoch=nb_epoch,
                    verbose=2, validation_data=(X_valid, y_valid))

assert(history.history['val_acc'][-1] > 0.9), "The validation accuracy is: %.3f" % history.history['val_acc'][-1]
# Out:
# Train on 34799 samples, validate on 12630 samples
# Epoch 1/1000
# 366s - loss: 3.4192 - acc: 0.1020 - val_loss: 2.8808 - val_acc: 0.2891
# Epoch 2/1000
# 368s - loss: 2.4134 - acc: 0.3469 - val_loss: 1.6884 - val_acc: 0.5205
# Epoch 3/1000
# 389s - loss: 1.6025 - acc: 0.5206 - val_loss: 1.1476 - val_acc: 0.6718
# Epoch 4/1000
# 403s - loss: 1.1633 - acc: 0.6370 - val_loss: 0.8135 - val_acc: 0.7797
# Epoch 5/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-5118db0193e8> in <module>()
#      20 history = model.fit(X_train, y_train,
#      21                     batch_size=batch_size, nb_epoch=nb_epoch,
# ---> 22                     verbose=2, validation_data=(X_valid, y_valid))
#      23
#      24 # STOP: Do not change the tests below. Your implementation should pass these tests.
#
# /Users/dc/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/models.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     670                               class_weight=class_weight,
#     671                               sample_weight=sample_weight,
# --> 672                               initial_epoch=initial_epoch)
#     673
#     674     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /Users/dc/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch)
#    1195                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1196                               callback_metrics=callback_metrics,
# -> 1197                               initial_epoch=initial_epoch)
#    1198
#    1199     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /Users/dc/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#     890                 batch_logs['size'] = len(batch_ids)
#     891                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 892                 outs = f(ins_batch)
#     893                 if not isinstance(outs, list):
#     894                     outs = [outs]
#
# /Users/dc/anaconda/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    1920         session = get_session()
#    1921         updated = session.run(self.outputs + [self.updates_op],
# -> 1922                               feed_dict=feed_dict)
#    1923         return updated[:len(self.outputs)]
#    1924
#
# /Users/dc/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/dc/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /Users/dc/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/dc/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /Users/dc/anaconda/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
model.evaluate(X_test, y_test)
