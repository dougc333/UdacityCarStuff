# %% [markdown]
# ### Test Cells
# #test notebook. Cut and paste 100 EPOCH results from Titan X here and the test code for errors/class

# %%
top_k_vals = []
top_k_vals.append([0.978146,0.0109876,0.00767156 ,0.00146429,0.000890397])
label=[]
label.append([0,1,4,8,18])
top_k_vals.append([0.995239,0.00228423,0.00165667 ,0.000819964,1.35885e-07])
label.append([5,1,0,3,6])
top_k_vals.append([0.296937,0.16502,0.141899 ,0.0723655,0.0681367])
label.append([12,2,42,6,25])
top_k_vals.append([0.999551,0.000268922,0.000135727 ,1.21371e-05,1.07661e-05])
label.append([12,13,40,14,25])
top_k_vals.append([0.978146,0.0109876,0.00767156 ,0.00146429,0.000890397])
label.append([0,1,4,8,18])

# %%
###We can see the loss accuracy decrease till .541 then it increases. This is the validation accuracy and not the Loss. 
###This was run on a TitanX. At .541 we have run 98 epochs. 
batch Accuracy = 0.572
EPOCH 1 ...
Validation Accuracy = 0.542

batch Accuracy = 0.839
EPOCH 2 ...
Validation Accuracy = 0.754

batch Accuracy = 0.916
EPOCH 3 ...
Validation Accuracy = 0.822

batch Accuracy = 0.936
EPOCH 4 ...
Validation Accuracy = 0.860

batch Accuracy = 0.973
EPOCH 5 ...
Validation Accuracy = 0.874

batch Accuracy = 0.960
EPOCH 6 ...
Validation Accuracy = 0.885

batch Accuracy = 0.967
EPOCH 7 ...
Validation Accuracy = 0.901

batch Accuracy = 0.973
EPOCH 8 ...
Validation Accuracy = 0.906

batch Accuracy = 0.990
EPOCH 9 ...
Validation Accuracy = 0.912

batch Accuracy = 0.980
EPOCH 10 ...
Validation Accuracy = 0.917

batch Accuracy = 0.973
EPOCH 11 ...
Validation Accuracy = 0.918

batch Accuracy = 0.990
EPOCH 12 ...
Validation Accuracy = 0.923

batch Accuracy = 0.983
EPOCH 13 ...
Validation Accuracy = 0.925

batch Accuracy = 0.983
EPOCH 14 ...
Validation Accuracy = 0.927

batch Accuracy = 0.993
EPOCH 15 ...
Validation Accuracy = 0.925

batch Accuracy = 0.983
EPOCH 16 ...
Validation Accuracy = 0.927

batch Accuracy = 0.983
EPOCH 17 ...
Validation Accuracy = 0.929

batch Accuracy = 1.000
EPOCH 18 ...
Validation Accuracy = 0.934

batch Accuracy = 0.990
EPOCH 19 ...
Validation Accuracy = 0.928

batch Accuracy = 0.993
EPOCH 20 ...
Validation Accuracy = 0.934

batch Accuracy = 0.990
EPOCH 21 ...
Validation Accuracy = 0.934

batch Accuracy = 0.997
EPOCH 22 ...
Validation Accuracy = 0.933

batch Accuracy = 1.000
EPOCH 23 ...
Validation Accuracy = 0.933

batch Accuracy = 0.993
EPOCH 24 ...
Validation Accuracy = 0.936

batch Accuracy = 0.993
EPOCH 25 ...
Validation Accuracy = 0.930

batch Accuracy = 0.997
EPOCH 26 ...
Validation Accuracy = 0.935

batch Accuracy = 0.997
EPOCH 27 ...
Validation Accuracy = 0.940

batch Accuracy = 1.000
EPOCH 28 ...
Validation Accuracy = 0.936

batch Accuracy = 0.997
EPOCH 29 ...
Validation Accuracy = 0.936

batch Accuracy = 0.997
EPOCH 30 ...
Validation Accuracy = 0.938

batch Accuracy = 1.000
EPOCH 31 ...
Validation Accuracy = 0.940

batch Accuracy = 1.000
EPOCH 32 ...
Validation Accuracy = 0.939

batch Accuracy = 0.993
EPOCH 33 ...
Validation Accuracy = 0.940

batch Accuracy = 1.000
EPOCH 34 ...
Validation Accuracy = 0.941

batch Accuracy = 0.997
EPOCH 35 ...
Validation Accuracy = 0.943

batch Accuracy = 1.000
EPOCH 36 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 37 ...
Validation Accuracy = 0.943

batch Accuracy = 0.997
EPOCH 38 ...
Validation Accuracy = 0.943

batch Accuracy = 1.000
EPOCH 39 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 40 ...
Validation Accuracy = 0.944

batch Accuracy = 1.000
EPOCH 41 ...
Validation Accuracy = 0.942

batch Accuracy = 0.997
EPOCH 42 ...
Validation Accuracy = 0.940

batch Accuracy = 0.997
EPOCH 43 ...
Validation Accuracy = 0.943

batch Accuracy = 0.997
EPOCH 44 ...
Validation Accuracy = 0.942

batch Accuracy = 0.997
EPOCH 45 ...
Validation Accuracy = 0.943

batch Accuracy = 0.990
EPOCH 46 ...
Validation Accuracy = 0.943

batch Accuracy = 0.997
EPOCH 47 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 48 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 49 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 50 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 51 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 52 ...
Validation Accuracy = 0.943

batch Accuracy = 1.000
EPOCH 53 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 54 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 55 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 56 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 57 ...
Validation Accuracy = 0.944

batch Accuracy = 1.000
EPOCH 58 ...
Validation Accuracy = 0.942

batch Accuracy = 1.000
EPOCH 59 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 60 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 61 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 62 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 63 ...
Validation Accuracy = 0.946

batch Accuracy = 0.997
EPOCH 64 ...
Validation Accuracy = 0.943

batch Accuracy = 1.000
EPOCH 65 ...
Validation Accuracy = 0.946

batch Accuracy = 0.997
EPOCH 66 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 67 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 68 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 69 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 70 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 71 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 72 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 73 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 74 ...
Validation Accuracy = 0.944

batch Accuracy = 0.997
EPOCH 75 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 76 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 77 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 78 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 79 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 80 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 81 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 82 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 83 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 84 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 85 ...
Validation Accuracy = 0.944

batch Accuracy = 1.000
EPOCH 86 ...
Validation Accuracy = 0.947

batch Accuracy = 0.997
EPOCH 87 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 88 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 89 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 90 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 91 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 92 ...
Validation Accuracy = 0.944

batch Accuracy = 0.997
EPOCH 93 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 94 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 95 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 96 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 97 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 98 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 99 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 100 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 101 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 102 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 103 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 104 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 105 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 106 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 107 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 108 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 109 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 110 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 111 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 112 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 113 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 114 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 115 ...
Validation Accuracy = 0.945

batch Accuracy = 1.000
EPOCH 116 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 117 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 118 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 119 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 120 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 121 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 122 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 123 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 124 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 125 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 126 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 127 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 128 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 129 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 130 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 131 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 132 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 133 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 134 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 135 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 136 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 137 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 138 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 139 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 140 ...
Validation Accuracy = 0.946

batch Accuracy = 1.000
EPOCH 141 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 142 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 143 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 144 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 145 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 146 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 147 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 148 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 149 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 150 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 151 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 152 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 153 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 154 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 155 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 156 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 157 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 158 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 159 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 160 ...
Validation Accuracy = 0.953

batch Accuracy = 1.000
EPOCH 161 ...
Validation Accuracy = 0.953

batch Accuracy = 1.000
EPOCH 162 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 163 ...
Validation Accuracy = 0.953

batch Accuracy = 1.000
EPOCH 164 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 165 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 166 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 167 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 168 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 169 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 170 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 171 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 172 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 173 ...
Validation Accuracy = 0.954

batch Accuracy = 1.000
EPOCH 174 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 175 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 176 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 177 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 178 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 179 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 180 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 181 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 182 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 183 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 184 ...
Validation Accuracy = 0.947

batch Accuracy = 1.000
EPOCH 185 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 186 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 187 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 188 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 189 ...
Validation Accuracy = 0.949

batch Accuracy = 1.000
EPOCH 190 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 191 ...
Validation Accuracy = 0.950

batch Accuracy = 1.000
EPOCH 192 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 193 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 194 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 195 ...
Validation Accuracy = 0.953

batch Accuracy = 1.000
EPOCH 196 ...
Validation Accuracy = 0.948

batch Accuracy = 1.000
EPOCH 197 ...
Validation Accuracy = 0.953

batch Accuracy = 1.000
EPOCH 198 ...
Validation Accuracy = 0.951

batch Accuracy = 1.000
EPOCH 199 ...
Validation Accuracy = 0.952

batch Accuracy = 1.000
EPOCH 200 ...
Validation Accuracy = 0.952

Model saved
Out[31]:
0.95225658750873843

# %%
### Run the predictions here.
### Feel free to use as many code cells as needed.

#testMe=[]
# you should be able to put the whole array here!!!
#X_test_pp_format or X_valid_pp_format into the feed_dict
#testMe.append(X_test_pp_format[0])
#T_test=np.array(testMe)
#print('T_test shape:',T_test.shape)

with tf.Session() as sess:
    saver.restore(sess, save_path )
    softmax = tf.nn.softmax(logits)
    top_k_val, top_k_idx = tf.nn.top_k(softmax, k=5)
    
    #top_k_vals, top_k_idxs = sess.run([top_k_val, top_k_idx], feed_dict={x: T_test, keep_prob : 1.0})
    top_k_vals, top_k_idxs = sess.run([top_k_val, top_k_idx], feed_dict={x: X_test_pp_format, keep_prob : 1.0})

# %%
#run after X_test_pp_format
print (top_k_val.get_shape())
print (top_k_idxs.shape)
print (top_k_idx[0].get_shape())
print ("test image 0 is:", y_test[0])
tmp = top_k_idxs.shape[0]
print ('tmp:',tmp)
numHit=[]
for y in range(top_k_idxs.shape[0]):
    for x in range(len(top_k_idxs[0])):
        #print ('x:',x, 'y:',y)
        if(x==0 and (y_test[y]!=top_k_idxs[y][x])):
            print ('Mismatch..' ,(x,y))
            numHit.append((x,y))
        if x==0:
            print ('prob:', top_k_vals[y][x],' class:',top_k_idxs[y][x], 'y_test:',y_test[y])
        else:
            print ('     prob:', top_k_vals[y][x],' class:',top_k_idxs[y][x], 'y_test:',y_test[y])
    
print (len(numHit)) #855 no match in test set

# %%
### Partial Output from above
I cant paste the entire output .. too large... they can't grade this if I leave this in the workbook'
